# %% [markdown]
# # Tarea 1 Grupo

# %% [markdown]
# Contextualizar un poco (archivos secundarios y despues el principal con las respuestas a las preguntas)

# %% [markdown]
# ## Archivos secundarios

# %%
from random import seed, random
from numpy.random import poisson, negative_binomial
from numpy.random import seed as npseed



def simulation_parameters(total, delta_t,s):
    seed(s)
    npseed(s)
    r_p = {i: poisson(15) for i in range(total)} # El tiempo de recuperacion
    c_p = {i: min(r_p[i], negative_binomial(6,0.5)) for i in range(total)} # Tiempo en que se da cuenta
    contagios = {t: {i: random() for i in range(total)} for t in range(delta_t + 1)}

    return r_p, c_p, contagios
### es ineficiente, porque nos da el numero de probabilidad de que se contagie en cada día aunque no se reunan (son numeros inuyiles)
## que no es tan importante, pero lo tuvimos en cuenta para el orden
##y nos generaria problemas

# %% [markdown]
# Aca explicas Personas importante exlicar sus atributos  y los metodos pasar dia y contacto

# %%
class Persona:
    def __init__(self,id,probabilidad_contagio):
        self._id = id #esto es por bonito nada más, para identificar a cada persona
        self._probabilidad_contagio = probabilidad_contagio #probabilidad de contagio inicial de cada persona
        self.estado = "S" # S: sano; A asintomatico; E enfermo ; M muerto ; R recuperado
        self._dias_recuperacion = 0 #cuenta regresiva a recuperacion, se inicializan en 0 porque al principio no saben si tienen la enfermedad
        self._dias_sintomas = 0 #cuenta regresiva a presentar sintomas
    @property
    def dias_recuperacion(self):  # manejan los cambios de estado (todas las propertys @)
        return self._dias_recuperacion
    @dias_recuperacion.setter
    def dias_recuperacion(self, a):
        if(a <= 0):
            self._dias_recuperacion = 0
            self.estado = "R"
        self._dias_recuperacion = a
    @property
    def dias_sintomas(self):
        return self._dias_sintomas
    @dias_sintomas.setter
    def dias_sintomas(self, a):    #dias hasta que empiezan a tener sintomas
        if(a <= 0):
            self._dias_sintomas = 0
            self.estado = "E"                    #usamos clases por facilidad de modificar y clasificar estados, agregar todo tipo de informacion
        self._dias_sintomas = a
    def contacto(self,dado,dias_recuperacion,dias_sintomas):        #dado es para ver si se contagio o no, dado el numero del dado
        if self.estado == "S" and dado <= self._probabilidad_contagio:
            self.estado = "A"
            self._dias_recuperacion = dias_recuperacion
            self._dias_sintomas = min(dias_sintomas, dias_recuperacion)

    def pasar_dia (self):
        if self.estado in ["A","E"]:                 #solo afecta si estas asintomatico o enfermo, sino estas sano o muerto, no afecta
            if self.estado == "A":
                self.dias_sintomas -= 1
            self.dias_recuperacion -= 1

    def __repr__(self):                     #los dos para que se vea bonito
        return self.estado+str(self._id)
    def __str__(self):
        if self.estado == "S":
            return f"Soy {self._id}, estoy Sano, P contagio {self._probabilidad_contagio}"
        if self.estado == "A":
            return f"Soy {self._id}, estoy Asintomatico,sintomas:{self._dias_sintomas}, recuperacion {self._dias_recuperacion}"
        if self.estado == "E":
            return f"Soy {self._id}, estoy Enfermo, recuperacion {self._dias_recuperacion}"
        if self.estado == "R":
            return f"Soy {self._id}, estoy Recuperado "

# %%
#Codigo_Graficos.py
import matplotlib.pyplot as plt
import numpy as np


def graficar_infectados(diccionario):
    cantidad_casos_totales = diccionario["it"]   #it es infectados totales
    cantidad_casos_recuperados = diccionario["r"] #recueprados
    cantidad_casos_actuales = diccionario["i"] #infectados actuales
    x = diccionario["t"]   # dia
    plt.plot(x, cantidad_casos_actuales,label= 'casos actuales')
    plt.plot(x, cantidad_casos_recuperados, label= 'casos recuperados')
    plt.plot(x, cantidad_casos_totales, label= 'casos totales')
    plt.ylabel('Cantidad de infectados')
    plt.xlabel('Días')
    plt.title("Infectados en función del tiempo")

    plt.legend(loc=0)
    plt.savefig("grafico_infectados.png")
    mostrar=plt.show()
    return mostrar

# %% [markdown]
# # Main script
# ## Librerias Y VERBOSIDAD
# explicacion de librerias
#
# Las comentadas no son necesarias en jupyther notebook porque ya se ejecutaron las cendas
# Si verboso es true se imprimiran cosas en la consola

# %%
from collections import defaultdict          #para ordenarse en los momentos de reunion
#from personas import Persona                #clase creada, mencionada en la celda anterior
#from simulation_parameters import simulation_parameters    #para llamar a la funcion simulatio_parameters
#from Codigo_Graficos import graficar_infectados            #para llamar a la funcion
import os  #https://stackoverflow.com/questions/7165749/open-file-in-a-relative-location-in-python
import re  #https://stackoverflow.com/questions/1249388/removing-all-non-numeric-characters-from-string-in-python
import copy  #https://www.geeksforgeeks.org/copy-python-deep-copy-shallow-copy/
import time  #medir los tiempos tiempos de simulacion, para medir la eficienci
VERBOSIDAD = 1 # 0 es no imprimir nada, 1 minimo (recomendado), 2 es imprimir lo basico  , 3 es imprimir los detalles

# %% [markdown]
# explicación (1.1 Nuestro grafo..)

# %%
#archivo main.py
def crear_grafo ( personas, reuniones):
    """ Crea un default diccionario donde las llaves son los dias y los elemntos son una
    lista con los sets con los id de las personas que se juntaron """
    data_reuniones = defaultdict(list)
    with open (reuniones) as file:    #abrir archivo
        linea = file.__next__()       #nos da la unica linea del archivo
    inter = linea.split("({")         #lee la base de datos

    for i in range(1,len(inter)):
        parcial = set(map(int,inter[i].split("}")[0].split(", ")))    #usamos sets porque es mas eficiente la busqueda, facilita todo
        dia = int(re.sub("[^0-9]", "",inter[i].split("}")[1] ))       
        data_reuniones[dia].append(parcial)
    #reuniones son los arcos
    #cantidad de dia desde la infeccion que su estado de Enfermos con Sintomas
    """ Crea un diccionario donde las llaves son las id y los elementos son instancias de la clase personas"""
    data_personas = dict()    #no es defaultdict porque no tiene sentido preguntar por personas que no existen (gigo)
    with open (personas) as file:   #fue un diccionario en vez de una lista, porque al principio estaba  desordenado y ahora no, pero ya esta hecho
        linea = file.__next__().strip("{}")
    inter = linea.split(", ")
    for i in inter:
        persona = i.split(":")
        id = int(persona[0])
        data_personas[id]= Persona(id,float(persona[1]))   #aca se guardo en cada nodo, una instancia para cada persona
    return (data_personas,data_reuniones)

# aca va el codigo de la funcion
script_dir = os.path.dirname("Informe.ipynb") #<-- absolute dir the script is in
CODIGO = 1500 #Cantidad de pacientes
personas = os.path.join(script_dir, f"Instancias/personas_{CODIGO}.txt")     #aca se crea el grafo (incluyendo las siguientes 3 lineas)
reuniones = os.path.join(script_dir, f"Instancias/reuniones_{CODIGO}.txt")
grafo = crear_grafo(personas,reuniones)

# %% [markdown]
# Aca explicas determinar contagiados importante notar la eficiencia de los sets (esta es la pregunta 1) (hacemos sets porque es muy eficientes los metodos union e intersection y es facil revisar si algo esta dentro del set)

# %%
#archivo main.py

#bastante efciciente creo que el por caso seria si todas las personas se juntaran todos los dias
def determinar_contagiados(grafo, p0 ,delta_dias):
    #grafo es un grafo formado por la estructura de la funcion crear_grafo
    #p0 es in integer con el indice del paciente 0
    #dia_final número de días transcurridos
    posibles = set()
    posibles.add(p0)
    data_reuniones = grafo[1]
    for t in range (0,delta_dias+1):
        if VERBOSIDAD>1:
            print(f"POSIBLES al principio del DIA {t}",posibles)
        for reunion in data_reuniones[t]:
            if posibles.intersection(reunion):
                posibles = posibles.union(reunion)
                if VERBOSIDAD > 3:
                    print(F"Reunion infectada DIA{t}:",reunion, "culpables:",posibles.intersection(reunion))
    if VERBOSIDAD > 1:
        print(F"\n POSIBLES al final del dia {t}",posibles)
    return posibles

#acá se debería correr la función
script_dir = os.path.dirname("Informe.ipynb") #<-- absolute dir the script is in
CODIGO = 1500 #Cantidad de pacientes
personas = os.path.join(script_dir, f"Instancias/personas_{CODIGO}.txt")     #aca se crea el grafo (incluyendo las siguientes 3 lineas)
reuniones = os.path.join(script_dir, f"Instancias/reuniones_{CODIGO}.txt")
grafo = crear_grafo(personas,reuniones)
p0 = 33 #paciente original
delta_dias = 7 # Cantidad de dias
determinar_contagiados(grafo,p0,delta_dias)
# Out:
# {0,
#  5,
#  9,
#  11,
#  14,
#  20,
#  22,
#  24,
#  25,
#  26,
#  27,
#  29,
#  32,
#  33,
#  34,
#  35,
#  37,
#  45,
#  48,
#  49,
#  50,
#  51,
#  54,
#  56,
#  58,
#  60,
#  64,
#  65,
#  69,
#  71,
#  72,
#  73,
#  77,
#  78,
#  80,
#  83,
#  84,
#  86,
#  89,
#  92,
#  95,
#  96,
#  98,
#  100,
#  102,
#  106,
#  108,
#  109,
#  115,
#  118,
#  121,
#  130,
#  131,
#  133,
#  134,
#  142,
#  147,
#  148,
#  157,
#  158,
#  160,
#  161,
#  163,
#  166,
#  168,
#  169,
#  173,
#  174,
#  175,
#  178,
#  184,
#  187,
#  188,
#  189,
#  193,
#  194,
#  195,
#  196,
#  199,
#  202,
#  203,
#  204,
#  208,
#  213,
#  215,
#  219,
#  228,
#  229,
#  231,
#  232,
#  236,
#  239,
#  241,
#  243,
#  246,
#  250,
#  253,
#  256,
#  257,
#  258,
#  260,
#  264,
#  266,
#  268,
#  272,
#  273,
#  275,
#  276,
#  277,
#  278,
#  283,
#  285,
#  286,
#  288,
#  290,
#  293,
#  296,
#  300,
#  301,
#  302,
#  303,
#  304,
#  307,
#  308,
#  313,
#  318,
#  326,
#  329,
#  331,
#  335,
#  336,
#  340,
#  344,
#  345,
#  346,
#  347,
#  348,
#  350,
#  353,
#  356,
#  362,
#  365,
#  368,
#  369,
#  371,
#  372,
#  374,
#  375,
#  378,
#  379,
#  387,
#  390,
#  391,
#  392,
#  395,
#  396,
#  397,
#  400,
#  404,
#  405,
#  406,
#  410,
#  411,
#  412,
#  414,
#  421,
#  422,
#  425,
#  426,
#  427,
#  428,
#  431,
#  433,
#  434,
#  442,
#  443,
#  444,
#  445,
#  446,
#  449,
#  450,
#  452,
#  453,
#  454,
#  456,
#  457,
#  458,
#  464,
#  466,
#  468,
#  469,
#  472,
#  475,
#  476,
#  482,
#  484,
#  487,
#  493,
#  494,
#  495,
#  497,
#  499,
#  500,
#  501,
#  502,
#  504,
#  506,
#  507,
#  509,
#  512,
#  520,
#  521,
#  523,
#  527,
#  528,
#  529,
#  530,
#  533,
#  536,
#  537,
#  539,
#  542,
#  543,
#  544,
#  545,
#  548,
#  549,
#  551,
#  553,
#  556,
#  558,
#  562,
#  569,
#  570,
#  571,
#  572,
#  574,
#  577,
#  578,
#  579,
#  584,
#  585,
#  589,
#  591,
#  592,
#  593,
#  594,
#  595,
#  596,
#  598,
#  606,
#  607,
#  612,
#  616,
#  617,
#  619,
#  620,
#  624,
#  628,
#  629,
#  630,
#  632,
#  633,
#  637,
#  642,
#  644,
#  655,
#  660,
#  666,
#  671,
#  672,
#  674,
#  676,
#  678,
#  679,
#  683,
#  684,
#  685,
#  686,
#  689,
#  690,
#  691,
#  692,
#  693,
#  696,
#  705,
#  706,
#  708,
#  709,
#  710,
#  714,
#  716,
#  718,
#  722,
#  723,
#  724,
#  725,
#  726,
#  727,
#  729,
#  731,
#  732,
#  733,
#  735,
#  737,
#  743,
#  744,
#  746,
#  749,
#  754,
#  755,
#  756,
#  757,
#  759,
#  767,
#  768,
#  769,
#  771,
#  779,
#  781,
#  784,
#  787,
#  790,
#  791,
#  792,
#  793,
#  797,
#  802,
#  804,
#  806,
#  807,
#  809,
#  810,
#  812,
#  813,
#  815,
#  816,
#  817,
#  819,
#  822,
#  823,
#  824,
#  826,
#  828,
#  830,
#  832,
#  834,
#  836,
#  841,
#  842,
#  849,
#  850,
#  851,
#  854,
#  856,
#  861,
#  864,
#  865,
#  867,
#  868,
#  872,
#  873,
#  875,
#  876,
#  881,
#  883,
#  885,
#  887,
#  889,
#  890,
#  892,
#  893,
#  895,
#  899,
#  901,
#  902,
#  903,
#  906,
#  907,
#  908,
#  909,
#  911,
#  917,
#  918,
#  919,
#  920,
#  922,
#  923,
#  925,
#  926,
#  933,
#  934,
#  936,
#  937,
#  938,
#  943,
#  944,
#  946,
#  949,
#  950,
#  953,
#  956,
#  959,
#  960,
#  962,
#  963,
#  965,
#  967,
#  970,
#  971,
#  972,
#  976,
#  979,
#  980,
#  981,
#  982,
#  985,
#  993,
#  994,
#  995,
#  997,
#  1002,
#  1003,
#  1004,
#  1005,
#  1007,
#  1008,
#  1010,
#  1013,
#  1015,
#  1017,
#  1018,
#  1020,
#  1022,
#  1023,
#  1029,
#  1030,
#  1031,
#  1032,
#  1033,
#  1035,
#  1037,
#  1038,
#  1039,
#  1041,
#  1042,
#  1047,
#  1048,
#  1052,
#  1053,
#  1058,
#  1060,
#  1062,
#  1064,
#  1065,
#  1066,
#  1069,
#  1073,
#  1080,
#  1081,
#  1084,
#  1085,
#  1087,
#  1088,
#  1089,
#  1090,
#  1092,
#  1093,
#  1095,
#  1097,
#  1101,
#  1103,
#  1104,
#  1106,
#  1107,
#  1110,
#  1115,
#  1117,
#  1119,
#  1121,
#  1125,
#  1127,
#  1128,
#  1131,
#  1132,
#  1133,
#  1134,
#  1136,
#  1137,
#  1138,
#  1142,
#  1143,
#  1145,
#  1147,
#  1151,
#  1154,
#  1155,
#  1158,
#  1159,
#  1162,
#  1166,
#  1168,
#  1170,
#  1173,
#  1175,
#  1176,
#  1177,
#  1179,
#  1184,
#  1187,
#  1192,
#  1193,
#  1198,
#  1199,
#  1202,
#  1203,
#  1206,
#  1209,
#  1213,
#  1221,
#  1222,
#  1223,
#  1226,
#  1227,
#  1228,
#  1232,
#  1236,
#  1237,
#  1246,
#  1251,
#  1252,
#  1254,
#  1256,
#  1258,
#  1259,
#  1262,
#  1263,
#  1269,
#  1274,
#  1276,
#  1278,
#  1280,
#  1282,
#  1284,
#  1288,
#  1290,
#  1293,
#  1294,
#  1298,
#  1299,
#  1305,
#  1307,
#  1308,
#  1310,
#  1312,
#  1313,
#  1314,
#  1316,
#  1323,
#  1326,
#  1329,
#  1332,
#  1335,
#  1336,
#  1337,
#  1338,
#  1339,
#  1341,
#  1342,
#  1343,
#  1345,
#  1346,
#  1347,
#  1348,
#  1349,
#  1350,
#  1351,
#  1352,
#  1359,
#  1366,
#  1367,
#  1369,
#  1370,
#  1371,
#  1372,
#  1374,
#  1377,
#  1384,
#  1387,
#  1388,
#  1390,
#  1392,
#  1393,
#  1394,
#  1396,
#  1397,
#  1398,
#  1401,
#  1406,
#  1407,
#  1409,
#  1412,
#  1413,
#  1419,
#  1421,
#  1422,
#  1423,
#  1425,
#  1427,
#  1429,
#  1431,
#  1432,
#  1435,
#  1437,
#  1438,
#  1440,
#  1442,
#  1443,
#  1445,
#  1446,
#  1449,
#  1451,
#  1454,
#  1455,
#  1458,
#  1459,
#  1461,
#  1463,
#  1465,
#  1466,
#  1473,
#  1474,
#  1475,
#  1476,
#  1478,
#  1480,
#  1481,
#  1482,
#  1486,
#  1490,
#  1491,
#  1492,
#  1495,
#  1496}

# %%
def simular_contagio( grafo, p0, delta_dias, s):
    #vectores = infectados actuales
    data_personas = grafo[0]          #primer elemento del grafo (los nodos)
    data_reuniones = grafo[1]          # segundo
    "Se simulan los parametros necesarios para cada persona"
    parametros = simulation_parameters(len(data_personas),delta_dias,s)
    dias_recuperacion = parametros[0]
    dias_sintomas = parametros[1]
    contagios = parametros[2]
    vectores = set()        #los que pueden contagiar
    vectores.add(p0)
    infectados = set()
    infectados.add(p0)
    recuperados = set()

    data_personas[p0].contacto(0,dias_recuperacion[p0] , dias_sintomas[p0])  ##inicilizar el tiempo para p0 con sus contadores
    datos_infectados = []
    datos_recuperados = []
    datos_it = []
    dias = []

    for t in range (0,delta_dias+1):
        if VERBOSIDAD > 1:
            print(f"Comienza DIA {t}")
            print("Inf:",len(infectados),"-Vect:",len(vectores),"-Rec:",len(recuperados))
        datos_infectados.append(len(infectados))
        datos_recuperados.append(len(recuperados))
        datos_it.append(len(recuperados)+len(infectados))     #guardando los datos de cada dia para ponerlos en el grafico
        dias.append(t)
        for reunion in data_reuniones[t]:
            culpables = vectores.intersection(reunion) #son los que infectaron la reunion, que tiene complejidad (buscar)
            if culpables:                    #si es que existen culpables, que es lo mismo que decir len(culpables)>0            
                for posible_contagiado in reunion - culpables:       # la resta es sacar los elementos iguales
                    id = posible_contagiado
                    if id not in recuperados and id not in infectados:   # si no esta en ninguno de los dos, esta sano
                        data_personas[id].contacto(contagios[t][id],dias_recuperacion[id] , dias_sintomas[id])  # ese contagios da el numero del dado,
       
        ##########################################################
        ##### VERDADERA FUENTE DE INEFICIENCIA DEL PROGRAMA ######
        ##########################################################
        # porque iteramos sobre todas las personas todos los dias O(m*n)   m:cantidad personas, n: cantidad de días
        # si queremos mejorar la eficiencia del codigo, esto es lo que hay que mejorar
        # podriamos llevar la cuenta de cambios de estado de las personas y asi tener el estado en cada momento del individuo, pero de esta forma,
        # perdemos la moldeabilidad y la escalabilidad del codigo (por ahora podría tener más caracteristicas el codigo(relaciones mas complejas,
        # mas enfermedades, muertes, entre otros factores) gracias a que los tratamos como objeto y no como una sola variable)
        infectados = set()
        vectores = set()
        recuperados = set()
        for i in range(0,len(data_personas)):                   
            data_personas[i].pasar_dia()
            if data_personas[i].estado == "A":
                vectores.add(i)
                infectados.add(i)
            elif data_personas[i].estado == "E":
                infectados.add(i)
            elif data_personas[i].estado == "R":
                recuperados.add(i)
            elif data_personas[i].estado == "S":
                pass
            else:
                print("ERROR ESTADO ANOMALO")
    if VERBOSIDAD:
        print(f"Fin del DIA {t}")
        print("Inf:",len(infectados),"-Vect:",len(vectores),"-Rec:",len(recuperados))
    return infectados,recuperados,{"t":dias,
            "i":datos_infectados,
            "it":datos_it,
            "r":datos_recuperados}

#acá se debería correr la función
VERBOSIDAD = 1
script_dir = os.path.dirname("Informe.ipynb") #<-- absolute dir the script is in
CODIGO = 1500 #Cantidad de pacientes
personas = os.path.join(script_dir, f"Instancias/personas_{CODIGO}.txt")     #aca se crea el grafo (incluyendo las siguientes 3 lineas)
reuniones = os.path.join(script_dir, f"Instancias/reuniones_{CODIGO}.txt")
grafo = crear_grafo(personas,reuniones)
p0 = 33 #paciente original
delta_dias = 75 # Cantidad de dias
p0 = 33 #paciente original
delta_dias = 75 # Cantidad de dias
SEED = 6
resultados = simular_contagio( grafo, 33, delta_dias, SEED)
graficar_infectados(resultados[2])
# Out:
# Fin del DIA 75
# Inf: 0 -Vect: 0 -Rec: 1425

# %% [markdown]
# # ADVERTENCIA: Correr esta celda puede demorar un tiempo (5 min aporx)

# %%
def probabilidad_contagio(grafo,p0,delta_dias):
    Cantidad = len(grafo[0])       #se obtiene la cantidad de personas
    SIMULACIONES = 1000
    conteos = {i: 0 for i in range(Cantidad)}      #esto crea un diccionario con las llaves siendo el id de la persona, y con todos los elementos en 0
    tiempo_simulaciones = 0                        #crea el tiempo para las simulaciones
    for s in range (0,SIMULACIONES):               #s es la semilla para poder hacer la cantidad de simulaciones requerida (1000), para tener diferentes semillas
        copia_grafo = copy.deepcopy(grafo)         # en vez de crear grafos para cada simulacion, los copiamos y los vamos sobreescribiendo
        if VERBOSIDAD:
            print("-"*45,f"SIMUACION SEMILLA: {s}","-"*45)
        t_inicio=time.time()
        infectados = simular_contagio(copia_grafo, p0, delta_dias,s)[0]   ##aca da la complejidad del algoritmo que es O(|s|*|Cantidad|)  (cada simulacion se demora lac antidad de dias asi que son lo mismo)
        tiempo_simulacion = time.time()-t_inicio
        tiempo_simulaciones += tiempo_simulacion        #autoexplicativo
        if VERBOSIDAD: # es lo mismo que if verbosidad >=1
            print(F"Tiempo de simulacion{tiempo_simulacion}")
        for i in range(Cantidad):
            if i in infectados:
                conteos[i] += 1       #en este for, se va actualizando el valor del diccionario, que nos dice cuantas veces se enfermo cada weon
    for i in range (0, Cantidad):
        conteos[i]= float(conteos[i])/float(SIMULACIONES) #ya esta hecha la division
        if conteos[i] and VERBOSIDAD > 1:
            print(f"Pasinte{i}: probabilidad: {conteos[i]}") #pos simplicidad solo printea los que son distintos de 0 
    print(f"Con {Cantidad} personas y {delta_dias} dias se demora {tiempo_simulaciones}s en hacer {SIMULACIONES} simulaciones\nPromedio de simulacion{tiempo_simulaciones/SIMULACIONES} s")
    return conteos

#acá se debería correr la función
script_dir = os.path.dirname("Informe.ipynb") #<-- absolute dir the script is in
CODIGO = 1500 #Cantidad de pacientes
personas = os.path.join(script_dir, f"Instancias/personas_{CODIGO}.txt")     #aca se crea el grafo (incluyendo las siguientes 3 lineas)
reuniones = os.path.join(script_dir, f"Instancias/reuniones_{CODIGO}.txt")
grafo = crear_grafo(personas,reuniones)
p0 = 33 #paciente original
delta_dias = 75 # Cantidad de dias
p0 = 33 #paciente original
delta_dias = 22 # Cantidad de dias
probabilidades = probabilidad_contagio(grafo,p0,delta_dias)
# Out:
# --------------------------------------------- SIMUACION SEMILLA: 0 ---------------------------------------------
# Fin del DIA 22
# Inf: 794 -Vect: 114 -Rec: 571
# Tiempo de simulacion0.08243703842163086
# --------------------------------------------- SIMUACION SEMILLA: 1 ---------------------------------------------
# Fin del DIA 22
# Inf: 953 -Vect: 180 -Rec: 366
# Tiempo de simulacion0.10214710235595703
# --------------------------------------------- SIMUACION SEMILLA: 2 ---------------------------------------------
# Fin del DIA 22
# Inf: 816 -Vect: 146 -Rec: 544
# Tiempo de simulacion0.08831000328063965
# --------------------------------------------- SIMUACION SEMILLA: 3 ---------------------------------------------
# Fin del DIA 22
# Inf: 928 -Vect: 156 -Rec: 385
# Tiempo de simulacion0.08396697044372559
# --------------------------------------------- SIMUACION SEMILLA: 4 ---------------------------------------------
# Fin del DIA 22
# Inf: 840 -Vect: 135 -Rec: 507
# Tiempo de simulacion0.08644413948059082
# --------------------------------------------- SIMUACION SEMILLA: 5 ---------------------------------------------
# Fin del DIA 22
# Inf: 870 -Vect: 148 -Rec: 481
# Tiempo de simulacion0.08908200263977051
# --------------------------------------------- SIMUACION SEMILLA: 6 ---------------------------------------------
# Fin del DIA 22
# Inf: 830 -Vect: 122 -Rec: 536
# Tiempo de simulacion0.09553885459899902
# --------------------------------------------- SIMUACION SEMILLA: 7 ---------------------------------------------
# Fin del DIA 22
# Inf: 879 -Vect: 161 -Rec: 450
# Tiempo de simulacion0.14701008796691895
# --------------------------------------------- SIMUACION SEMILLA: 8 ---------------------------------------------
# Fin del DIA 22
# Inf: 806 -Vect: 116 -Rec: 550
# Tiempo de simulacion0.08852195739746094
# --------------------------------------------- SIMUACION SEMILLA: 9 ---------------------------------------------
# Fin del DIA 22
# Inf: 971 -Vect: 209 -Rec: 352
# Tiempo de simulacion0.1301131248474121
# --------------------------------------------- SIMUACION SEMILLA: 10 ---------------------------------------------
# Fin del DIA 22
# Inf: 759 -Vect: 101 -Rec: 607
# Tiempo de simulacion0.07998991012573242
# --------------------------------------------- SIMUACION SEMILLA: 11 ---------------------------------------------
# Fin del DIA 22
# Inf: 841 -Vect: 125 -Rec: 532
# Tiempo de simulacion0.08343505859375
# --------------------------------------------- SIMUACION SEMILLA: 12 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.07411599159240723
# --------------------------------------------- SIMUACION SEMILLA: 13 ---------------------------------------------
# Fin del DIA 22
# Inf: 809 -Vect: 117 -Rec: 527
# Tiempo de simulacion0.0903470516204834
# --------------------------------------------- SIMUACION SEMILLA: 14 ---------------------------------------------
# Fin del DIA 22
# Inf: 806 -Vect: 133 -Rec: 562
# Tiempo de simulacion0.14300799369812012
# --------------------------------------------- SIMUACION SEMILLA: 15 ---------------------------------------------
# Fin del DIA 22
# Inf: 845 -Vect: 135 -Rec: 526
# Tiempo de simulacion0.09293413162231445
# --------------------------------------------- SIMUACION SEMILLA: 16 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.0685582160949707
# --------------------------------------------- SIMUACION SEMILLA: 17 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06599617004394531
# --------------------------------------------- SIMUACION SEMILLA: 18 ---------------------------------------------
# Fin del DIA 22
# Inf: 830 -Vect: 146 -Rec: 520
# Tiempo de simulacion0.16617894172668457
# --------------------------------------------- SIMUACION SEMILLA: 19 ---------------------------------------------
# Fin del DIA 22
# Inf: 831 -Vect: 139 -Rec: 539
# Tiempo de simulacion0.2065432071685791
# --------------------------------------------- SIMUACION SEMILLA: 20 ---------------------------------------------
# Fin del DIA 22
# Inf: 835 -Vect: 153 -Rec: 517
# Tiempo de simulacion0.09912896156311035
# --------------------------------------------- SIMUACION SEMILLA: 21 ---------------------------------------------
# Fin del DIA 22
# Inf: 842 -Vect: 144 -Rec: 523
# Tiempo de simulacion0.11719465255737305
# --------------------------------------------- SIMUACION SEMILLA: 22 ---------------------------------------------
# Fin del DIA 22
# Inf: 802 -Vect: 118 -Rec: 567
# Tiempo de simulacion0.12089872360229492
# --------------------------------------------- SIMUACION SEMILLA: 23 ---------------------------------------------
# Fin del DIA 22
# Inf: 835 -Vect: 147 -Rec: 516
# Tiempo de simulacion0.09371709823608398
# --------------------------------------------- SIMUACION SEMILLA: 24 ---------------------------------------------
# Fin del DIA 22
# Inf: 818 -Vect: 131 -Rec: 523
# Tiempo de simulacion0.09366393089294434
# --------------------------------------------- SIMUACION SEMILLA: 25 ---------------------------------------------
# Fin del DIA 22
# Inf: 823 -Vect: 132 -Rec: 503
# Tiempo de simulacion0.0855569839477539
# --------------------------------------------- SIMUACION SEMILLA: 26 ---------------------------------------------
# Fin del DIA 22
# Inf: 898 -Vect: 174 -Rec: 433
# Tiempo de simulacion0.08762288093566895
# --------------------------------------------- SIMUACION SEMILLA: 27 ---------------------------------------------
# Fin del DIA 22
# Inf: 844 -Vect: 137 -Rec: 514
# Tiempo de simulacion0.10276007652282715
# --------------------------------------------- SIMUACION SEMILLA: 28 ---------------------------------------------
# Fin del DIA 22
# Inf: 826 -Vect: 156 -Rec: 521
# Tiempo de simulacion0.08130502700805664
# --------------------------------------------- SIMUACION SEMILLA: 29 ---------------------------------------------
# Fin del DIA 22
# Inf: 782 -Vect: 133 -Rec: 592
# Tiempo de simulacion0.09021592140197754
# --------------------------------------------- SIMUACION SEMILLA: 30 ---------------------------------------------
# Fin del DIA 22
# Inf: 824 -Vect: 162 -Rec: 520
# Tiempo de simulacion0.09816789627075195
# --------------------------------------------- SIMUACION SEMILLA: 31 ---------------------------------------------
# Fin del DIA 22
# Inf: 827 -Vect: 148 -Rec: 535
# Tiempo de simulacion0.09717226028442383
# --------------------------------------------- SIMUACION SEMILLA: 32 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06719708442687988
# --------------------------------------------- SIMUACION SEMILLA: 33 ---------------------------------------------
# Fin del DIA 22
# Inf: 794 -Vect: 117 -Rec: 569
# Tiempo de simulacion0.09560823440551758
# --------------------------------------------- SIMUACION SEMILLA: 34 ---------------------------------------------
# Fin del DIA 22
# Inf: 778 -Vect: 115 -Rec: 609
# Tiempo de simulacion0.11567306518554688
# --------------------------------------------- SIMUACION SEMILLA: 35 ---------------------------------------------
# Fin del DIA 22
# Inf: 860 -Vect: 160 -Rec: 496
# Tiempo de simulacion0.08718729019165039
# --------------------------------------------- SIMUACION SEMILLA: 36 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.07384181022644043
# --------------------------------------------- SIMUACION SEMILLA: 37 ---------------------------------------------
# Fin del DIA 22
# Inf: 813 -Vect: 125 -Rec: 544
# Tiempo de simulacion0.09401082992553711
# --------------------------------------------- SIMUACION SEMILLA: 38 ---------------------------------------------
# Fin del DIA 22
# Inf: 899 -Vect: 164 -Rec: 448
# Tiempo de simulacion0.09557986259460449
# --------------------------------------------- SIMUACION SEMILLA: 39 ---------------------------------------------
# Fin del DIA 22
# Inf: 860 -Vect: 143 -Rec: 522
# Tiempo de simulacion0.08362412452697754
# --------------------------------------------- SIMUACION SEMILLA: 40 ---------------------------------------------
# Fin del DIA 22
# Inf: 810 -Vect: 122 -Rec: 553
# Tiempo de simulacion0.08387422561645508
# --------------------------------------------- SIMUACION SEMILLA: 41 ---------------------------------------------
# Fin del DIA 22
# Inf: 797 -Vect: 129 -Rec: 547
# Tiempo de simulacion0.08610415458679199
# --------------------------------------------- SIMUACION SEMILLA: 42 ---------------------------------------------
# Fin del DIA 22
# Inf: 914 -Vect: 206 -Rec: 419
# Tiempo de simulacion0.09850597381591797
# --------------------------------------------- SIMUACION SEMILLA: 43 ---------------------------------------------
# Fin del DIA 22
# Inf: 871 -Vect: 146 -Rec: 483
# Tiempo de simulacion0.08584332466125488
# --------------------------------------------- SIMUACION SEMILLA: 44 ---------------------------------------------
# Fin del DIA 22
# Inf: 775 -Vect: 121 -Rec: 593
# Tiempo de simulacion0.08675575256347656
# --------------------------------------------- SIMUACION SEMILLA: 45 ---------------------------------------------
# Fin del DIA 22
# Inf: 815 -Vect: 138 -Rec: 543
# Tiempo de simulacion0.08165788650512695
# --------------------------------------------- SIMUACION SEMILLA: 46 ---------------------------------------------
# Fin del DIA 22
# Inf: 882 -Vect: 155 -Rec: 473
# Tiempo de simulacion0.07984519004821777
# --------------------------------------------- SIMUACION SEMILLA: 47 ---------------------------------------------
# Fin del DIA 22
# Inf: 760 -Vect: 119 -Rec: 597
# Tiempo de simulacion0.10635113716125488
# --------------------------------------------- SIMUACION SEMILLA: 48 ---------------------------------------------
# Fin del DIA 22
# Inf: 897 -Vect: 163 -Rec: 446
# Tiempo de simulacion0.08215498924255371
# --------------------------------------------- SIMUACION SEMILLA: 49 ---------------------------------------------
# Fin del DIA 22
# Inf: 825 -Vect: 132 -Rec: 533
# Tiempo de simulacion0.08176779747009277
# --------------------------------------------- SIMUACION SEMILLA: 50 ---------------------------------------------
# Fin del DIA 22
# Inf: 828 -Vect: 152 -Rec: 520
# Tiempo de simulacion0.09305405616760254
# --------------------------------------------- SIMUACION SEMILLA: 51 ---------------------------------------------
# Fin del DIA 22
# Inf: 836 -Vect: 146 -Rec: 514
# Tiempo de simulacion0.09479093551635742
# --------------------------------------------- SIMUACION SEMILLA: 52 ---------------------------------------------
# Fin del DIA 22
# Inf: 799 -Vect: 136 -Rec: 552
# Tiempo de simulacion0.08407998085021973
# --------------------------------------------- SIMUACION SEMILLA: 53 ---------------------------------------------
# Fin del DIA 22
# Inf: 865 -Vect: 169 -Rec: 480
# Tiempo de simulacion0.12094593048095703
# --------------------------------------------- SIMUACION SEMILLA: 54 ---------------------------------------------
# Fin del DIA 22
# Inf: 804 -Vect: 126 -Rec: 549
# Tiempo de simulacion0.1069180965423584
# --------------------------------------------- SIMUACION SEMILLA: 55 ---------------------------------------------
# Fin del DIA 22
# Inf: 859 -Vect: 146 -Rec: 492
# Tiempo de simulacion0.1061089038848877
# --------------------------------------------- SIMUACION SEMILLA: 56 ---------------------------------------------
# Fin del DIA 22
# Inf: 855 -Vect: 140 -Rec: 492
# Tiempo de simulacion0.12027907371520996
# --------------------------------------------- SIMUACION SEMILLA: 57 ---------------------------------------------
# Fin del DIA 22
# Inf: 856 -Vect: 142 -Rec: 491
# Tiempo de simulacion0.08723902702331543
# --------------------------------------------- SIMUACION SEMILLA: 58 ---------------------------------------------
# Fin del DIA 22
# Inf: 828 -Vect: 136 -Rec: 541
# Tiempo de simulacion0.09561014175415039
# --------------------------------------------- SIMUACION SEMILLA: 59 ---------------------------------------------
# Fin del DIA 22
# Inf: 838 -Vect: 123 -Rec: 526
# Tiempo de simulacion0.10696911811828613
# --------------------------------------------- SIMUACION SEMILLA: 60 ---------------------------------------------
# Fin del DIA 22
# Inf: 807 -Vect: 110 -Rec: 529
# Tiempo de simulacion0.0902099609375
# --------------------------------------------- SIMUACION SEMILLA: 61 ---------------------------------------------
# Fin del DIA 22
# Inf: 836 -Vect: 137 -Rec: 506
# Tiempo de simulacion0.08236289024353027
# --------------------------------------------- SIMUACION SEMILLA: 62 ---------------------------------------------
# Fin del DIA 22
# Inf: 835 -Vect: 137 -Rec: 500
# Tiempo de simulacion0.07722711563110352
# --------------------------------------------- SIMUACION SEMILLA: 63 ---------------------------------------------
# Fin del DIA 22
# Inf: 856 -Vect: 147 -Rec: 508
# Tiempo de simulacion0.08749985694885254
# --------------------------------------------- SIMUACION SEMILLA: 64 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06658315658569336
# --------------------------------------------- SIMUACION SEMILLA: 65 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06357598304748535
# --------------------------------------------- SIMUACION SEMILLA: 66 ---------------------------------------------
# Fin del DIA 22
# Inf: 831 -Vect: 156 -Rec: 517
# Tiempo de simulacion0.0902719497680664
# --------------------------------------------- SIMUACION SEMILLA: 67 ---------------------------------------------
# Fin del DIA 22
# Inf: 767 -Vect: 128 -Rec: 575
# Tiempo de simulacion0.0804588794708252
# --------------------------------------------- SIMUACION SEMILLA: 68 ---------------------------------------------
# Fin del DIA 22
# Inf: 917 -Vect: 173 -Rec: 421
# Tiempo de simulacion0.08397912979125977
# --------------------------------------------- SIMUACION SEMILLA: 69 ---------------------------------------------
# Fin del DIA 22
# Inf: 906 -Vect: 166 -Rec: 431
# Tiempo de simulacion0.09016299247741699
# --------------------------------------------- SIMUACION SEMILLA: 70 ---------------------------------------------
# Fin del DIA 22
# Inf: 800 -Vect: 122 -Rec: 551
# Tiempo de simulacion0.09165215492248535
# --------------------------------------------- SIMUACION SEMILLA: 71 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.07583308219909668
# --------------------------------------------- SIMUACION SEMILLA: 72 ---------------------------------------------
# Fin del DIA 22
# Inf: 849 -Vect: 145 -Rec: 502
# Tiempo de simulacion0.20297813415527344
# --------------------------------------------- SIMUACION SEMILLA: 73 ---------------------------------------------
# Fin del DIA 22
# Inf: 932 -Vect: 175 -Rec: 413
# Tiempo de simulacion0.08535289764404297
# --------------------------------------------- SIMUACION SEMILLA: 74 ---------------------------------------------
# Fin del DIA 22
# Inf: 1 -Vect: 0 -Rec: 0
# Tiempo de simulacion0.10583996772766113
# --------------------------------------------- SIMUACION SEMILLA: 75 ---------------------------------------------
# Fin del DIA 22
# Inf: 845 -Vect: 148 -Rec: 515
# Tiempo de simulacion0.1312851905822754
# --------------------------------------------- SIMUACION SEMILLA: 76 ---------------------------------------------
# Fin del DIA 22
# Inf: 821 -Vect: 122 -Rec: 526
# Tiempo de simulacion0.08804702758789062
# --------------------------------------------- SIMUACION SEMILLA: 77 ---------------------------------------------
# Fin del DIA 22
# Inf: 898 -Vect: 155 -Rec: 448
# Tiempo de simulacion0.1165461540222168
# --------------------------------------------- SIMUACION SEMILLA: 78 ---------------------------------------------
# Fin del DIA 22
# Inf: 871 -Vect: 136 -Rec: 491
# Tiempo de simulacion0.09760308265686035
# --------------------------------------------- SIMUACION SEMILLA: 79 ---------------------------------------------
# Fin del DIA 22
# Inf: 909 -Vect: 162 -Rec: 449
# Tiempo de simulacion0.14420199394226074
# --------------------------------------------- SIMUACION SEMILLA: 80 ---------------------------------------------
# Fin del DIA 22
# Inf: 835 -Vect: 147 -Rec: 513
# Tiempo de simulacion0.08696508407592773
# --------------------------------------------- SIMUACION SEMILLA: 81 ---------------------------------------------
# Fin del DIA 22
# Inf: 827 -Vect: 129 -Rec: 540
# Tiempo de simulacion0.09761810302734375
# --------------------------------------------- SIMUACION SEMILLA: 82 ---------------------------------------------
# Fin del DIA 22
# Inf: 829 -Vect: 147 -Rec: 525
# Tiempo de simulacion0.08754420280456543
# --------------------------------------------- SIMUACION SEMILLA: 83 ---------------------------------------------
# Fin del DIA 22
# Inf: 940 -Vect: 196 -Rec: 381
# Tiempo de simulacion0.09671688079833984
# --------------------------------------------- SIMUACION SEMILLA: 84 ---------------------------------------------
# Fin del DIA 22
# Inf: 862 -Vect: 155 -Rec: 485
# Tiempo de simulacion0.10949015617370605
# --------------------------------------------- SIMUACION SEMILLA: 85 ---------------------------------------------
# Fin del DIA 22
# Inf: 810 -Vect: 115 -Rec: 552
# Tiempo de simulacion0.11193704605102539
# --------------------------------------------- SIMUACION SEMILLA: 86 ---------------------------------------------
# Fin del DIA 22
# Inf: 903 -Vect: 166 -Rec: 444
# Tiempo de simulacion0.13007688522338867
# --------------------------------------------- SIMUACION SEMILLA: 87 ---------------------------------------------
# Fin del DIA 22
# Inf: 855 -Vect: 140 -Rec: 497
# Tiempo de simulacion0.12645602226257324
# --------------------------------------------- SIMUACION SEMILLA: 88 ---------------------------------------------
# Fin del DIA 22
# Inf: 830 -Vect: 147 -Rec: 533
# Tiempo de simulacion0.09895110130310059
# --------------------------------------------- SIMUACION SEMILLA: 89 ---------------------------------------------
# Fin del DIA 22
# Inf: 1011 -Vect: 215 -Rec: 309
# Tiempo de simulacion0.08864903450012207
# --------------------------------------------- SIMUACION SEMILLA: 90 ---------------------------------------------
# Fin del DIA 22
# Inf: 796 -Vect: 126 -Rec: 563
# Tiempo de simulacion0.1317119598388672
# --------------------------------------------- SIMUACION SEMILLA: 91 ---------------------------------------------
# Fin del DIA 22
# Inf: 859 -Vect: 160 -Rec: 513
# Tiempo de simulacion0.1301271915435791
# --------------------------------------------- SIMUACION SEMILLA: 92 ---------------------------------------------
# Fin del DIA 22
# Inf: 866 -Vect: 151 -Rec: 483
# Tiempo de simulacion0.12060999870300293
# --------------------------------------------- SIMUACION SEMILLA: 93 ---------------------------------------------
# Fin del DIA 22
# Inf: 856 -Vect: 129 -Rec: 508
# Tiempo de simulacion0.125596284866333
# --------------------------------------------- SIMUACION SEMILLA: 94 ---------------------------------------------
# Fin del DIA 22
# Inf: 879 -Vect: 177 -Rec: 450
# Tiempo de simulacion0.08695197105407715
# --------------------------------------------- SIMUACION SEMILLA: 95 ---------------------------------------------
# Fin del DIA 22
# Inf: 811 -Vect: 133 -Rec: 550
# Tiempo de simulacion0.12472391128540039
# --------------------------------------------- SIMUACION SEMILLA: 96 ---------------------------------------------
# Fin del DIA 22
# Inf: 973 -Vect: 208 -Rec: 368
# Tiempo de simulacion0.11735010147094727
# --------------------------------------------- SIMUACION SEMILLA: 97 ---------------------------------------------
# Fin del DIA 22
# Inf: 806 -Vect: 107 -Rec: 564
# Tiempo de simulacion0.15183115005493164
# --------------------------------------------- SIMUACION SEMILLA: 98 ---------------------------------------------
# Fin del DIA 22
# Inf: 886 -Vect: 155 -Rec: 477
# Tiempo de simulacion0.12826967239379883
# --------------------------------------------- SIMUACION SEMILLA: 99 ---------------------------------------------
# Fin del DIA 22
# Inf: 877 -Vect: 153 -Rec: 454
# Tiempo de simulacion0.15398478507995605
# --------------------------------------------- SIMUACION SEMILLA: 100 ---------------------------------------------
# Fin del DIA 22
# Inf: 878 -Vect: 159 -Rec: 461
# Tiempo de simulacion0.12286067008972168
# --------------------------------------------- SIMUACION SEMILLA: 101 ---------------------------------------------
# Fin del DIA 22
# Inf: 776 -Vect: 107 -Rec: 579
# Tiempo de simulacion0.14129924774169922
# --------------------------------------------- SIMUACION SEMILLA: 102 ---------------------------------------------
# Fin del DIA 22
# Inf: 797 -Vect: 130 -Rec: 567
# Tiempo de simulacion0.08495807647705078
# --------------------------------------------- SIMUACION SEMILLA: 103 ---------------------------------------------
# Fin del DIA 22
# Inf: 842 -Vect: 135 -Rec: 510
# Tiempo de simulacion0.15423297882080078
# --------------------------------------------- SIMUACION SEMILLA: 104 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.0936732292175293
# --------------------------------------------- SIMUACION SEMILLA: 105 ---------------------------------------------
# Fin del DIA 22
# Inf: 932 -Vect: 179 -Rec: 401
# Tiempo de simulacion0.11752676963806152
# --------------------------------------------- SIMUACION SEMILLA: 106 ---------------------------------------------
# Fin del DIA 22
# Inf: 881 -Vect: 152 -Rec: 463
# Tiempo de simulacion0.08865189552307129
# --------------------------------------------- SIMUACION SEMILLA: 107 ---------------------------------------------
# Fin del DIA 22
# Inf: 827 -Vect: 123 -Rec: 519
# Tiempo de simulacion0.10081291198730469
# --------------------------------------------- SIMUACION SEMILLA: 108 ---------------------------------------------
# Fin del DIA 22
# Inf: 813 -Vect: 134 -Rec: 538
# Tiempo de simulacion0.12403202056884766
# --------------------------------------------- SIMUACION SEMILLA: 109 ---------------------------------------------
# Fin del DIA 22
# Inf: 926 -Vect: 150 -Rec: 426
# Tiempo de simulacion0.12171006202697754
# --------------------------------------------- SIMUACION SEMILLA: 110 ---------------------------------------------
# Fin del DIA 22
# Inf: 821 -Vect: 153 -Rec: 519
# Tiempo de simulacion0.12771320343017578
# --------------------------------------------- SIMUACION SEMILLA: 111 ---------------------------------------------
# Fin del DIA 22
# Inf: 868 -Vect: 168 -Rec: 474
# Tiempo de simulacion0.08824491500854492
# --------------------------------------------- SIMUACION SEMILLA: 112 ---------------------------------------------
# Fin del DIA 22
# Inf: 837 -Vect: 136 -Rec: 516
# Tiempo de simulacion0.0995931625366211
# --------------------------------------------- SIMUACION SEMILLA: 113 ---------------------------------------------
# Fin del DIA 22
# Inf: 880 -Vect: 156 -Rec: 465
# Tiempo de simulacion0.12805604934692383
# --------------------------------------------- SIMUACION SEMILLA: 114 ---------------------------------------------
# Fin del DIA 22
# Inf: 835 -Vect: 134 -Rec: 519
# Tiempo de simulacion0.13380908966064453
# --------------------------------------------- SIMUACION SEMILLA: 115 ---------------------------------------------
# Fin del DIA 22
# Inf: 802 -Vect: 126 -Rec: 550
# Tiempo de simulacion0.09216499328613281
# --------------------------------------------- SIMUACION SEMILLA: 116 ---------------------------------------------
# Fin del DIA 22
# Inf: 877 -Vect: 168 -Rec: 446
# Tiempo de simulacion0.11708712577819824
# --------------------------------------------- SIMUACION SEMILLA: 117 ---------------------------------------------
# Fin del DIA 22
# Inf: 869 -Vect: 158 -Rec: 507
# Tiempo de simulacion0.1294240951538086
# --------------------------------------------- SIMUACION SEMILLA: 118 ---------------------------------------------
# Fin del DIA 22
# Inf: 831 -Vect: 147 -Rec: 543
# Tiempo de simulacion0.11156892776489258
# --------------------------------------------- SIMUACION SEMILLA: 119 ---------------------------------------------
# Fin del DIA 22
# Inf: 843 -Vect: 129 -Rec: 522
# Tiempo de simulacion0.12557530403137207
# --------------------------------------------- SIMUACION SEMILLA: 120 ---------------------------------------------
# Fin del DIA 22
# Inf: 813 -Vect: 115 -Rec: 556
# Tiempo de simulacion0.12205696105957031
# --------------------------------------------- SIMUACION SEMILLA: 121 ---------------------------------------------
# Fin del DIA 22
# Inf: 998 -Vect: 208 -Rec: 298
# Tiempo de simulacion0.14039397239685059
# --------------------------------------------- SIMUACION SEMILLA: 122 ---------------------------------------------
# Fin del DIA 22
# Inf: 956 -Vect: 180 -Rec: 364
# Tiempo de simulacion0.13589906692504883
# --------------------------------------------- SIMUACION SEMILLA: 123 ---------------------------------------------
# Fin del DIA 22
# Inf: 957 -Vect: 211 -Rec: 356
# Tiempo de simulacion0.1352698802947998
# --------------------------------------------- SIMUACION SEMILLA: 124 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.10364794731140137
# --------------------------------------------- SIMUACION SEMILLA: 125 ---------------------------------------------
# Fin del DIA 22
# Inf: 963 -Vect: 177 -Rec: 375
# Tiempo de simulacion0.1301121711730957
# --------------------------------------------- SIMUACION SEMILLA: 126 ---------------------------------------------
# Fin del DIA 22
# Inf: 847 -Vect: 143 -Rec: 496
# Tiempo de simulacion0.09090399742126465
# --------------------------------------------- SIMUACION SEMILLA: 127 ---------------------------------------------
# Fin del DIA 22
# Inf: 875 -Vect: 155 -Rec: 478
# Tiempo de simulacion0.0864560604095459
# --------------------------------------------- SIMUACION SEMILLA: 128 ---------------------------------------------
# Fin del DIA 22
# Inf: 864 -Vect: 149 -Rec: 498
# Tiempo de simulacion0.11000514030456543
# --------------------------------------------- SIMUACION SEMILLA: 129 ---------------------------------------------
# Fin del DIA 22
# Inf: 826 -Vect: 134 -Rec: 529
# Tiempo de simulacion0.1246190071105957
# --------------------------------------------- SIMUACION SEMILLA: 130 ---------------------------------------------
# Fin del DIA 22
# Inf: 806 -Vect: 134 -Rec: 551
# Tiempo de simulacion0.08952212333679199
# --------------------------------------------- SIMUACION SEMILLA: 131 ---------------------------------------------
# Fin del DIA 22
# Inf: 835 -Vect: 145 -Rec: 516
# Tiempo de simulacion0.10242319107055664
# --------------------------------------------- SIMUACION SEMILLA: 132 ---------------------------------------------
# Fin del DIA 22
# Inf: 841 -Vect: 143 -Rec: 529
# Tiempo de simulacion0.09394097328186035
# --------------------------------------------- SIMUACION SEMILLA: 133 ---------------------------------------------
# Fin del DIA 22
# Inf: 881 -Vect: 142 -Rec: 468
# Tiempo de simulacion0.15361881256103516
# --------------------------------------------- SIMUACION SEMILLA: 134 ---------------------------------------------
# Fin del DIA 22
# Inf: 876 -Vect: 154 -Rec: 460
# Tiempo de simulacion0.1333608627319336
# --------------------------------------------- SIMUACION SEMILLA: 135 ---------------------------------------------
# Fin del DIA 22
# Inf: 777 -Vect: 120 -Rec: 604
# Tiempo de simulacion0.09880495071411133
# --------------------------------------------- SIMUACION SEMILLA: 136 ---------------------------------------------
# Fin del DIA 22
# Inf: 811 -Vect: 129 -Rec: 545
# Tiempo de simulacion0.08778810501098633
# --------------------------------------------- SIMUACION SEMILLA: 137 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.09210085868835449
# --------------------------------------------- SIMUACION SEMILLA: 138 ---------------------------------------------
# Fin del DIA 22
# Inf: 807 -Vect: 128 -Rec: 557
# Tiempo de simulacion0.10700106620788574
# --------------------------------------------- SIMUACION SEMILLA: 139 ---------------------------------------------
# Fin del DIA 22
# Inf: 885 -Vect: 174 -Rec: 483
# Tiempo de simulacion0.08611583709716797
# --------------------------------------------- SIMUACION SEMILLA: 140 ---------------------------------------------
# Fin del DIA 22
# Inf: 866 -Vect: 158 -Rec: 484
# Tiempo de simulacion0.1304309368133545
# --------------------------------------------- SIMUACION SEMILLA: 141 ---------------------------------------------
# Fin del DIA 22
# Inf: 860 -Vect: 157 -Rec: 506
# Tiempo de simulacion0.1347970962524414
# --------------------------------------------- SIMUACION SEMILLA: 142 ---------------------------------------------
# Fin del DIA 22
# Inf: 793 -Vect: 115 -Rec: 554
# Tiempo de simulacion0.0993797779083252
# --------------------------------------------- SIMUACION SEMILLA: 143 ---------------------------------------------
# Fin del DIA 22
# Inf: 893 -Vect: 164 -Rec: 465
# Tiempo de simulacion0.13629913330078125
# --------------------------------------------- SIMUACION SEMILLA: 144 ---------------------------------------------
# Fin del DIA 22
# Inf: 805 -Vect: 109 -Rec: 550
# Tiempo de simulacion0.12393712997436523
# --------------------------------------------- SIMUACION SEMILLA: 145 ---------------------------------------------
# Fin del DIA 22
# Inf: 915 -Vect: 148 -Rec: 440
# Tiempo de simulacion0.21639585494995117
# --------------------------------------------- SIMUACION SEMILLA: 146 ---------------------------------------------
# Fin del DIA 22
# Inf: 911 -Vect: 148 -Rec: 427
# Tiempo de simulacion0.12857508659362793
# --------------------------------------------- SIMUACION SEMILLA: 147 ---------------------------------------------
# Fin del DIA 22
# Inf: 816 -Vect: 133 -Rec: 530
# Tiempo de simulacion0.11250710487365723
# --------------------------------------------- SIMUACION SEMILLA: 148 ---------------------------------------------
# Fin del DIA 22
# Inf: 794 -Vect: 140 -Rec: 578
# Tiempo de simulacion0.1466062068939209
# --------------------------------------------- SIMUACION SEMILLA: 149 ---------------------------------------------
# Fin del DIA 22
# Inf: 806 -Vect: 123 -Rec: 548
# Tiempo de simulacion0.13999295234680176
# --------------------------------------------- SIMUACION SEMILLA: 150 ---------------------------------------------
# Fin del DIA 22
# Inf: 798 -Vect: 143 -Rec: 537
# Tiempo de simulacion0.09329581260681152
# --------------------------------------------- SIMUACION SEMILLA: 151 ---------------------------------------------
# Fin del DIA 22
# Inf: 919 -Vect: 169 -Rec: 425
# Tiempo de simulacion0.11589670181274414
# --------------------------------------------- SIMUACION SEMILLA: 152 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.07793688774108887
# --------------------------------------------- SIMUACION SEMILLA: 153 ---------------------------------------------
# Fin del DIA 22
# Inf: 905 -Vect: 167 -Rec: 409
# Tiempo de simulacion0.1023406982421875
# --------------------------------------------- SIMUACION SEMILLA: 154 ---------------------------------------------
# Fin del DIA 22
# Inf: 846 -Vect: 135 -Rec: 519
# Tiempo de simulacion0.08651614189147949
# --------------------------------------------- SIMUACION SEMILLA: 155 ---------------------------------------------
# Fin del DIA 22
# Inf: 791 -Vect: 150 -Rec: 573
# Tiempo de simulacion0.08703994750976562
# --------------------------------------------- SIMUACION SEMILLA: 156 ---------------------------------------------
# Fin del DIA 22
# Inf: 908 -Vect: 165 -Rec: 431
# Tiempo de simulacion0.08858513832092285
# --------------------------------------------- SIMUACION SEMILLA: 157 ---------------------------------------------
# Fin del DIA 22
# Inf: 814 -Vect: 136 -Rec: 554
# Tiempo de simulacion0.09886813163757324
# --------------------------------------------- SIMUACION SEMILLA: 158 ---------------------------------------------
# Fin del DIA 22
# Inf: 962 -Vect: 204 -Rec: 372
# Tiempo de simulacion0.08853721618652344
# --------------------------------------------- SIMUACION SEMILLA: 159 ---------------------------------------------
# Fin del DIA 22
# Inf: 795 -Vect: 118 -Rec: 558
# Tiempo de simulacion0.09263896942138672
# --------------------------------------------- SIMUACION SEMILLA: 160 ---------------------------------------------
# Fin del DIA 22
# Inf: 860 -Vect: 141 -Rec: 479
# Tiempo de simulacion0.09808611869812012
# --------------------------------------------- SIMUACION SEMILLA: 161 ---------------------------------------------
# Fin del DIA 22
# Inf: 883 -Vect: 135 -Rec: 465
# Tiempo de simulacion0.07719922065734863
# --------------------------------------------- SIMUACION SEMILLA: 162 ---------------------------------------------
# Fin del DIA 22
# Inf: 884 -Vect: 154 -Rec: 462
# Tiempo de simulacion0.0800321102142334
# --------------------------------------------- SIMUACION SEMILLA: 163 ---------------------------------------------
# Fin del DIA 22
# Inf: 867 -Vect: 148 -Rec: 474
# Tiempo de simulacion0.08794999122619629
# --------------------------------------------- SIMUACION SEMILLA: 164 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06899404525756836
# --------------------------------------------- SIMUACION SEMILLA: 165 ---------------------------------------------
# Fin del DIA 22
# Inf: 850 -Vect: 148 -Rec: 519
# Tiempo de simulacion0.07964801788330078
# --------------------------------------------- SIMUACION SEMILLA: 166 ---------------------------------------------
# Fin del DIA 22
# Inf: 818 -Vect: 133 -Rec: 530
# Tiempo de simulacion0.07993912696838379
# --------------------------------------------- SIMUACION SEMILLA: 167 ---------------------------------------------
# Fin del DIA 22
# Inf: 802 -Vect: 140 -Rec: 565
# Tiempo de simulacion0.08219695091247559
# --------------------------------------------- SIMUACION SEMILLA: 168 ---------------------------------------------
# Fin del DIA 22
# Inf: 830 -Vect: 144 -Rec: 510
# Tiempo de simulacion0.08390092849731445
# --------------------------------------------- SIMUACION SEMILLA: 169 ---------------------------------------------
# Fin del DIA 22
# Inf: 808 -Vect: 129 -Rec: 563
# Tiempo de simulacion0.08589386940002441
# --------------------------------------------- SIMUACION SEMILLA: 170 ---------------------------------------------
# Fin del DIA 22
# Inf: 751 -Vect: 126 -Rec: 618
# Tiempo de simulacion0.08690595626831055
# --------------------------------------------- SIMUACION SEMILLA: 171 ---------------------------------------------
# Fin del DIA 22
# Inf: 852 -Vect: 145 -Rec: 501
# Tiempo de simulacion0.08746814727783203
# --------------------------------------------- SIMUACION SEMILLA: 172 ---------------------------------------------
# Fin del DIA 22
# Inf: 809 -Vect: 138 -Rec: 546
# Tiempo de simulacion0.08977007865905762
# --------------------------------------------- SIMUACION SEMILLA: 173 ---------------------------------------------
# Fin del DIA 22
# Inf: 998 -Vect: 204 -Rec: 332
# Tiempo de simulacion0.08951497077941895
# --------------------------------------------- SIMUACION SEMILLA: 174 ---------------------------------------------
# Fin del DIA 22
# Inf: 802 -Vect: 120 -Rec: 570
# Tiempo de simulacion0.09035897254943848
# --------------------------------------------- SIMUACION SEMILLA: 175 ---------------------------------------------
# Fin del DIA 22
# Inf: 869 -Vect: 150 -Rec: 476
# Tiempo de simulacion0.08104872703552246
# --------------------------------------------- SIMUACION SEMILLA: 176 ---------------------------------------------
# Fin del DIA 22
# Inf: 923 -Vect: 176 -Rec: 390
# Tiempo de simulacion0.0869147777557373
# --------------------------------------------- SIMUACION SEMILLA: 177 ---------------------------------------------
# Fin del DIA 22
# Inf: 821 -Vect: 128 -Rec: 531
# Tiempo de simulacion0.08206391334533691
# --------------------------------------------- SIMUACION SEMILLA: 178 ---------------------------------------------
# Fin del DIA 22
# Inf: 809 -Vect: 122 -Rec: 549
# Tiempo de simulacion0.07879090309143066
# --------------------------------------------- SIMUACION SEMILLA: 179 ---------------------------------------------
# Fin del DIA 22
# Inf: 821 -Vect: 114 -Rec: 512
# Tiempo de simulacion0.08730483055114746
# --------------------------------------------- SIMUACION SEMILLA: 180 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06364798545837402
# --------------------------------------------- SIMUACION SEMILLA: 181 ---------------------------------------------
# Fin del DIA 22
# Inf: 876 -Vect: 141 -Rec: 458
# Tiempo de simulacion0.08571791648864746
# --------------------------------------------- SIMUACION SEMILLA: 182 ---------------------------------------------
# Fin del DIA 22
# Inf: 902 -Vect: 174 -Rec: 452
# Tiempo de simulacion0.08544611930847168
# --------------------------------------------- SIMUACION SEMILLA: 183 ---------------------------------------------
# Fin del DIA 22
# Inf: 863 -Vect: 162 -Rec: 496
# Tiempo de simulacion0.08219194412231445
# --------------------------------------------- SIMUACION SEMILLA: 184 ---------------------------------------------
# Fin del DIA 22
# Inf: 795 -Vect: 122 -Rec: 573
# Tiempo de simulacion0.07927393913269043
# --------------------------------------------- SIMUACION SEMILLA: 185 ---------------------------------------------
# Fin del DIA 22
# Inf: 847 -Vect: 144 -Rec: 507
# Tiempo de simulacion0.0908360481262207
# --------------------------------------------- SIMUACION SEMILLA: 186 ---------------------------------------------
# Fin del DIA 22
# Inf: 852 -Vect: 146 -Rec: 523
# Tiempo de simulacion0.08080172538757324
# --------------------------------------------- SIMUACION SEMILLA: 187 ---------------------------------------------
# Fin del DIA 22
# Inf: 790 -Vect: 122 -Rec: 560
# Tiempo de simulacion0.0781710147857666
# --------------------------------------------- SIMUACION SEMILLA: 188 ---------------------------------------------
# Fin del DIA 22
# Inf: 808 -Vect: 106 -Rec: 560
# Tiempo de simulacion0.09267115592956543
# --------------------------------------------- SIMUACION SEMILLA: 189 ---------------------------------------------
# Fin del DIA 22
# Inf: 810 -Vect: 137 -Rec: 546
# Tiempo de simulacion0.08014297485351562
# --------------------------------------------- SIMUACION SEMILLA: 190 ---------------------------------------------
# Fin del DIA 22
# Inf: 830 -Vect: 158 -Rec: 539
# Tiempo de simulacion0.0789790153503418
# --------------------------------------------- SIMUACION SEMILLA: 191 ---------------------------------------------
# Fin del DIA 22
# Inf: 847 -Vect: 158 -Rec: 485
# Tiempo de simulacion0.08974885940551758
# --------------------------------------------- SIMUACION SEMILLA: 192 ---------------------------------------------
# Fin del DIA 22
# Inf: 902 -Vect: 163 -Rec: 438
# Tiempo de simulacion0.08610391616821289
# --------------------------------------------- SIMUACION SEMILLA: 193 ---------------------------------------------
# Fin del DIA 22
# Inf: 864 -Vect: 144 -Rec: 466
# Tiempo de simulacion0.08486604690551758
# --------------------------------------------- SIMUACION SEMILLA: 194 ---------------------------------------------
# Fin del DIA 22
# Inf: 822 -Vect: 131 -Rec: 534
# Tiempo de simulacion0.0812838077545166
# --------------------------------------------- SIMUACION SEMILLA: 195 ---------------------------------------------
# Fin del DIA 22
# Inf: 795 -Vect: 125 -Rec: 580
# Tiempo de simulacion0.08896088600158691
# --------------------------------------------- SIMUACION SEMILLA: 196 ---------------------------------------------
# Fin del DIA 22
# Inf: 872 -Vect: 155 -Rec: 473
# Tiempo de simulacion0.08807182312011719
# --------------------------------------------- SIMUACION SEMILLA: 197 ---------------------------------------------
# Fin del DIA 22
# Inf: 787 -Vect: 124 -Rec: 565
# Tiempo de simulacion0.08469200134277344
# --------------------------------------------- SIMUACION SEMILLA: 198 ---------------------------------------------
# Fin del DIA 22
# Inf: 822 -Vect: 133 -Rec: 535
# Tiempo de simulacion0.08748912811279297
# --------------------------------------------- SIMUACION SEMILLA: 199 ---------------------------------------------
# Fin del DIA 22
# Inf: 819 -Vect: 133 -Rec: 546
# Tiempo de simulacion0.07980990409851074
# --------------------------------------------- SIMUACION SEMILLA: 200 ---------------------------------------------
# Fin del DIA 22
# Inf: 899 -Vect: 168 -Rec: 450
# Tiempo de simulacion0.08196783065795898
# --------------------------------------------- SIMUACION SEMILLA: 201 ---------------------------------------------
# Fin del DIA 22
# Inf: 837 -Vect: 141 -Rec: 522
# Tiempo de simulacion0.0880889892578125
# --------------------------------------------- SIMUACION SEMILLA: 202 ---------------------------------------------
# Fin del DIA 22
# Inf: 853 -Vect: 149 -Rec: 505
# Tiempo de simulacion0.0812530517578125
# --------------------------------------------- SIMUACION SEMILLA: 203 ---------------------------------------------
# Fin del DIA 22
# Inf: 842 -Vect: 126 -Rec: 513
# Tiempo de simulacion0.07869982719421387
# --------------------------------------------- SIMUACION SEMILLA: 204 ---------------------------------------------
# Fin del DIA 22
# Inf: 905 -Vect: 159 -Rec: 456
# Tiempo de simulacion0.0811920166015625
# --------------------------------------------- SIMUACION SEMILLA: 205 ---------------------------------------------
# Fin del DIA 22
# Inf: 807 -Vect: 139 -Rec: 548
# Tiempo de simulacion0.09950590133666992
# --------------------------------------------- SIMUACION SEMILLA: 206 ---------------------------------------------
# Fin del DIA 22
# Inf: 976 -Vect: 219 -Rec: 347
# Tiempo de simulacion0.07857203483581543
# --------------------------------------------- SIMUACION SEMILLA: 207 ---------------------------------------------
# Fin del DIA 22
# Inf: 818 -Vect: 136 -Rec: 540
# Tiempo de simulacion0.08518195152282715
# --------------------------------------------- SIMUACION SEMILLA: 208 ---------------------------------------------
# Fin del DIA 22
# Inf: 860 -Vect: 159 -Rec: 490
# Tiempo de simulacion0.08725500106811523
# --------------------------------------------- SIMUACION SEMILLA: 209 ---------------------------------------------
# Fin del DIA 22
# Inf: 846 -Vect: 119 -Rec: 482
# Tiempo de simulacion0.08480286598205566
# --------------------------------------------- SIMUACION SEMILLA: 210 ---------------------------------------------
# Fin del DIA 22
# Inf: 831 -Vect: 132 -Rec: 537
# Tiempo de simulacion0.08705925941467285
# --------------------------------------------- SIMUACION SEMILLA: 211 ---------------------------------------------
# Fin del DIA 22
# Inf: 879 -Vect: 161 -Rec: 447
# Tiempo de simulacion0.08450174331665039
# --------------------------------------------- SIMUACION SEMILLA: 212 ---------------------------------------------
# Fin del DIA 22
# Inf: 818 -Vect: 136 -Rec: 538
# Tiempo de simulacion0.08555197715759277
# --------------------------------------------- SIMUACION SEMILLA: 213 ---------------------------------------------
# Fin del DIA 22
# Inf: 775 -Vect: 122 -Rec: 575
# Tiempo de simulacion0.08225488662719727
# --------------------------------------------- SIMUACION SEMILLA: 214 ---------------------------------------------
# Fin del DIA 22
# Inf: 885 -Vect: 156 -Rec: 469
# Tiempo de simulacion0.08176207542419434
# --------------------------------------------- SIMUACION SEMILLA: 215 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.0680389404296875
# --------------------------------------------- SIMUACION SEMILLA: 216 ---------------------------------------------
# Fin del DIA 22
# Inf: 866 -Vect: 136 -Rec: 499
# Tiempo de simulacion0.08259415626525879
# --------------------------------------------- SIMUACION SEMILLA: 217 ---------------------------------------------
# Fin del DIA 22
# Inf: 884 -Vect: 150 -Rec: 462
# Tiempo de simulacion0.08574295043945312
# --------------------------------------------- SIMUACION SEMILLA: 218 ---------------------------------------------
# Fin del DIA 22
# Inf: 826 -Vect: 134 -Rec: 522
# Tiempo de simulacion0.08351898193359375
# --------------------------------------------- SIMUACION SEMILLA: 219 ---------------------------------------------
# Fin del DIA 22
# Inf: 869 -Vect: 131 -Rec: 473
# Tiempo de simulacion0.08031105995178223
# --------------------------------------------- SIMUACION SEMILLA: 220 ---------------------------------------------
# Fin del DIA 22
# Inf: 849 -Vect: 150 -Rec: 512
# Tiempo de simulacion0.08518719673156738
# --------------------------------------------- SIMUACION SEMILLA: 221 ---------------------------------------------
# Fin del DIA 22
# Inf: 843 -Vect: 155 -Rec: 512
# Tiempo de simulacion0.08941006660461426
# --------------------------------------------- SIMUACION SEMILLA: 222 ---------------------------------------------
# Fin del DIA 22
# Inf: 878 -Vect: 143 -Rec: 441
# Tiempo de simulacion0.09039998054504395
# --------------------------------------------- SIMUACION SEMILLA: 223 ---------------------------------------------
# Fin del DIA 22
# Inf: 805 -Vect: 142 -Rec: 536
# Tiempo de simulacion0.08577203750610352
# --------------------------------------------- SIMUACION SEMILLA: 224 ---------------------------------------------
# Fin del DIA 22
# Inf: 893 -Vect: 178 -Rec: 439
# Tiempo de simulacion0.08200216293334961
# --------------------------------------------- SIMUACION SEMILLA: 225 ---------------------------------------------
# Fin del DIA 22
# Inf: 872 -Vect: 130 -Rec: 493
# Tiempo de simulacion0.08751583099365234
# --------------------------------------------- SIMUACION SEMILLA: 226 ---------------------------------------------
# Fin del DIA 22
# Inf: 805 -Vect: 133 -Rec: 545
# Tiempo de simulacion0.08592891693115234
# --------------------------------------------- SIMUACION SEMILLA: 227 ---------------------------------------------
# Fin del DIA 22
# Inf: 880 -Vect: 158 -Rec: 460
# Tiempo de simulacion0.09112024307250977
# --------------------------------------------- SIMUACION SEMILLA: 228 ---------------------------------------------
# Fin del DIA 22
# Inf: 875 -Vect: 135 -Rec: 460
# Tiempo de simulacion0.0803067684173584
# --------------------------------------------- SIMUACION SEMILLA: 229 ---------------------------------------------
# Fin del DIA 22
# Inf: 813 -Vect: 123 -Rec: 555
# Tiempo de simulacion0.0861349105834961
# --------------------------------------------- SIMUACION SEMILLA: 230 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.059266090393066406
# --------------------------------------------- SIMUACION SEMILLA: 231 ---------------------------------------------
# Fin del DIA 22
# Inf: 833 -Vect: 126 -Rec: 513
# Tiempo de simulacion0.08134889602661133
# --------------------------------------------- SIMUACION SEMILLA: 232 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06090903282165527
# --------------------------------------------- SIMUACION SEMILLA: 233 ---------------------------------------------
# Fin del DIA 22
# Inf: 809 -Vect: 120 -Rec: 550
# Tiempo de simulacion0.08080005645751953
# --------------------------------------------- SIMUACION SEMILLA: 234 ---------------------------------------------
# Fin del DIA 22
# Inf: 826 -Vect: 127 -Rec: 541
# Tiempo de simulacion0.0985410213470459
# --------------------------------------------- SIMUACION SEMILLA: 235 ---------------------------------------------
# Fin del DIA 22
# Inf: 917 -Vect: 170 -Rec: 461
# Tiempo de simulacion0.08318114280700684
# --------------------------------------------- SIMUACION SEMILLA: 236 ---------------------------------------------
# Fin del DIA 22
# Inf: 798 -Vect: 124 -Rec: 572
# Tiempo de simulacion0.07777690887451172
# --------------------------------------------- SIMUACION SEMILLA: 237 ---------------------------------------------
# Fin del DIA 22
# Inf: 855 -Vect: 153 -Rec: 500
# Tiempo de simulacion0.08253288269042969
# --------------------------------------------- SIMUACION SEMILLA: 238 ---------------------------------------------
# Fin del DIA 22
# Inf: 851 -Vect: 153 -Rec: 511
# Tiempo de simulacion0.08519911766052246
# --------------------------------------------- SIMUACION SEMILLA: 239 ---------------------------------------------
# Fin del DIA 22
# Inf: 916 -Vect: 186 -Rec: 408
# Tiempo de simulacion0.08224177360534668
# --------------------------------------------- SIMUACION SEMILLA: 240 ---------------------------------------------
# Fin del DIA 22
# Inf: 850 -Vect: 152 -Rec: 490
# Tiempo de simulacion0.08847808837890625
# ...
# Fin del DIA 22
# Inf: 811 -Vect: 132 -Rec: 549
# Tiempo de simulacion0.07986998558044434
# --------------------------------------------- SIMUACION SEMILLA: 921 ---------------------------------------------
# Fin del DIA 22
# Inf: 756 -Vect: 108 -Rec: 602
# Tiempo de simulacion0.0856781005859375
# --------------------------------------------- SIMUACION SEMILLA: 922 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.0589900016784668
# --------------------------------------------- SIMUACION SEMILLA: 923 ---------------------------------------------
# Fin del DIA 22
# Inf: 796 -Vect: 136 -Rec: 579
# Tiempo de simulacion0.08391118049621582
# --------------------------------------------- SIMUACION SEMILLA: 924 ---------------------------------------------
# Fin del DIA 22
# Inf: 763 -Vect: 115 -Rec: 600
# Tiempo de simulacion0.09089493751525879
# --------------------------------------------- SIMUACION SEMILLA: 925 ---------------------------------------------
# Fin del DIA 22
# Inf: 870 -Vect: 155 -Rec: 490
# Tiempo de simulacion0.08992981910705566
# --------------------------------------------- SIMUACION SEMILLA: 926 ---------------------------------------------
# Fin del DIA 22
# Inf: 867 -Vect: 173 -Rec: 485
# Tiempo de simulacion0.08047175407409668
# --------------------------------------------- SIMUACION SEMILLA: 927 ---------------------------------------------
# Fin del DIA 22
# Inf: 874 -Vect: 155 -Rec: 483
# Tiempo de simulacion0.09083127975463867
# --------------------------------------------- SIMUACION SEMILLA: 928 ---------------------------------------------
# Fin del DIA 22
# Inf: 835 -Vect: 131 -Rec: 515
# Tiempo de simulacion0.08783698081970215
# --------------------------------------------- SIMUACION SEMILLA: 929 ---------------------------------------------
# Fin del DIA 22
# Inf: 881 -Vect: 143 -Rec: 466
# Tiempo de simulacion0.08300590515136719
# --------------------------------------------- SIMUACION SEMILLA: 930 ---------------------------------------------
# Fin del DIA 22
# Inf: 801 -Vect: 135 -Rec: 548
# Tiempo de simulacion0.08674192428588867
# --------------------------------------------- SIMUACION SEMILLA: 931 ---------------------------------------------
# Fin del DIA 22
# Inf: 826 -Vect: 131 -Rec: 541
# Tiempo de simulacion0.09371709823608398
# --------------------------------------------- SIMUACION SEMILLA: 932 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.07128405570983887
# --------------------------------------------- SIMUACION SEMILLA: 933 ---------------------------------------------
# Fin del DIA 22
# Inf: 883 -Vect: 145 -Rec: 464
# Tiempo de simulacion0.09086918830871582
# --------------------------------------------- SIMUACION SEMILLA: 934 ---------------------------------------------
# Fin del DIA 22
# Inf: 761 -Vect: 107 -Rec: 601
# Tiempo de simulacion0.08105182647705078
# --------------------------------------------- SIMUACION SEMILLA: 935 ---------------------------------------------
# Fin del DIA 22
# Inf: 880 -Vect: 135 -Rec: 480
# Tiempo de simulacion0.08023285865783691
# --------------------------------------------- SIMUACION SEMILLA: 936 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06055784225463867
# --------------------------------------------- SIMUACION SEMILLA: 937 ---------------------------------------------
# Fin del DIA 22
# Inf: 849 -Vect: 144 -Rec: 512
# Tiempo de simulacion0.09458494186401367
# --------------------------------------------- SIMUACION SEMILLA: 938 ---------------------------------------------
# Fin del DIA 22
# Inf: 822 -Vect: 125 -Rec: 520
# Tiempo de simulacion0.1464099884033203
# --------------------------------------------- SIMUACION SEMILLA: 939 ---------------------------------------------
# Fin del DIA 22
# Inf: 830 -Vect: 145 -Rec: 536
# Tiempo de simulacion0.15183591842651367
# --------------------------------------------- SIMUACION SEMILLA: 940 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.08568096160888672
# --------------------------------------------- SIMUACION SEMILLA: 941 ---------------------------------------------
# Fin del DIA 22
# Inf: 868 -Vect: 159 -Rec: 481
# Tiempo de simulacion0.08933877944946289
# --------------------------------------------- SIMUACION SEMILLA: 942 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.07337403297424316
# --------------------------------------------- SIMUACION SEMILLA: 943 ---------------------------------------------
# Fin del DIA 22
# Inf: 811 -Vect: 153 -Rec: 564
# Tiempo de simulacion0.09068799018859863
# --------------------------------------------- SIMUACION SEMILLA: 944 ---------------------------------------------
# Fin del DIA 22
# Inf: 796 -Vect: 121 -Rec: 563
# Tiempo de simulacion0.15232396125793457
# --------------------------------------------- SIMUACION SEMILLA: 945 ---------------------------------------------
# Fin del DIA 22
# Inf: 872 -Vect: 143 -Rec: 465
# Tiempo de simulacion0.14272499084472656
# --------------------------------------------- SIMUACION SEMILLA: 946 ---------------------------------------------
# Fin del DIA 22
# Inf: 899 -Vect: 163 -Rec: 450
# Tiempo de simulacion0.1671900749206543
# --------------------------------------------- SIMUACION SEMILLA: 947 ---------------------------------------------
# Fin del DIA 22
# Inf: 775 -Vect: 126 -Rec: 579
# Tiempo de simulacion0.08858609199523926
# --------------------------------------------- SIMUACION SEMILLA: 948 ---------------------------------------------
# Fin del DIA 22
# Inf: 838 -Vect: 136 -Rec: 514
# Tiempo de simulacion0.11115193367004395
# --------------------------------------------- SIMUACION SEMILLA: 949 ---------------------------------------------
# Fin del DIA 22
# Inf: 804 -Vect: 136 -Rec: 554
# Tiempo de simulacion0.10790562629699707
# --------------------------------------------- SIMUACION SEMILLA: 950 ---------------------------------------------
# Fin del DIA 22
# Inf: 839 -Vect: 149 -Rec: 506
# Tiempo de simulacion0.08814597129821777
# --------------------------------------------- SIMUACION SEMILLA: 951 ---------------------------------------------
# Fin del DIA 22
# Inf: 844 -Vect: 148 -Rec: 498
# Tiempo de simulacion0.09984707832336426
# --------------------------------------------- SIMUACION SEMILLA: 952 ---------------------------------------------
# Fin del DIA 22
# Inf: 834 -Vect: 147 -Rec: 507
# Tiempo de simulacion0.11158514022827148
# --------------------------------------------- SIMUACION SEMILLA: 953 ---------------------------------------------
# Fin del DIA 22
# Inf: 860 -Vect: 149 -Rec: 480
# Tiempo de simulacion0.1063988208770752
# --------------------------------------------- SIMUACION SEMILLA: 954 ---------------------------------------------
# Fin del DIA 22
# Inf: 807 -Vect: 116 -Rec: 559
# Tiempo de simulacion0.09425091743469238
# --------------------------------------------- SIMUACION SEMILLA: 955 ---------------------------------------------
# Fin del DIA 22
# Inf: 837 -Vect: 145 -Rec: 511
# Tiempo de simulacion0.10335516929626465
# --------------------------------------------- SIMUACION SEMILLA: 956 ---------------------------------------------
# Fin del DIA 22
# Inf: 787 -Vect: 114 -Rec: 584
# Tiempo de simulacion0.09404373168945312
# --------------------------------------------- SIMUACION SEMILLA: 957 ---------------------------------------------
# Fin del DIA 22
# Inf: 819 -Vect: 141 -Rec: 535
# Tiempo de simulacion0.10971403121948242
# --------------------------------------------- SIMUACION SEMILLA: 958 ---------------------------------------------
# Fin del DIA 22
# Inf: 829 -Vect: 126 -Rec: 513
# Tiempo de simulacion0.09289097785949707
# --------------------------------------------- SIMUACION SEMILLA: 959 ---------------------------------------------
# Fin del DIA 22
# Inf: 847 -Vect: 129 -Rec: 511
# Tiempo de simulacion0.09444904327392578
# --------------------------------------------- SIMUACION SEMILLA: 960 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.07228803634643555
# --------------------------------------------- SIMUACION SEMILLA: 961 ---------------------------------------------
# Fin del DIA 22
# Inf: 897 -Vect: 155 -Rec: 455
# Tiempo de simulacion0.08172917366027832
# --------------------------------------------- SIMUACION SEMILLA: 962 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06482577323913574
# --------------------------------------------- SIMUACION SEMILLA: 963 ---------------------------------------------
# Fin del DIA 22
# Inf: 868 -Vect: 147 -Rec: 474
# Tiempo de simulacion0.11329317092895508
# --------------------------------------------- SIMUACION SEMILLA: 964 ---------------------------------------------
# Fin del DIA 22
# Inf: 880 -Vect: 150 -Rec: 454
# Tiempo de simulacion0.10230278968811035
# --------------------------------------------- SIMUACION SEMILLA: 965 ---------------------------------------------
# Fin del DIA 22
# Inf: 942 -Vect: 195 -Rec: 392
# Tiempo de simulacion0.10208797454833984
# --------------------------------------------- SIMUACION SEMILLA: 966 ---------------------------------------------
# Fin del DIA 22
# Inf: 840 -Vect: 135 -Rec: 522
# Tiempo de simulacion0.09079504013061523
# --------------------------------------------- SIMUACION SEMILLA: 967 ---------------------------------------------
# Fin del DIA 22
# Inf: 817 -Vect: 140 -Rec: 553
# Tiempo de simulacion0.08414101600646973
# --------------------------------------------- SIMUACION SEMILLA: 968 ---------------------------------------------
# Fin del DIA 22
# Inf: 799 -Vect: 122 -Rec: 561
# Tiempo de simulacion0.08232903480529785
# --------------------------------------------- SIMUACION SEMILLA: 969 ---------------------------------------------
# Fin del DIA 22
# Inf: 1002 -Vect: 185 -Rec: 324
# Tiempo de simulacion0.08098411560058594
# --------------------------------------------- SIMUACION SEMILLA: 970 ---------------------------------------------
# Fin del DIA 22
# Inf: 843 -Vect: 141 -Rec: 523
# Tiempo de simulacion0.08253693580627441
# --------------------------------------------- SIMUACION SEMILLA: 971 ---------------------------------------------
# Fin del DIA 22
# Inf: 865 -Vect: 147 -Rec: 489
# Tiempo de simulacion0.09021115303039551
# --------------------------------------------- SIMUACION SEMILLA: 972 ---------------------------------------------
# Fin del DIA 22
# Inf: 858 -Vect: 147 -Rec: 470
# Tiempo de simulacion0.16002798080444336
# --------------------------------------------- SIMUACION SEMILLA: 973 ---------------------------------------------
# Fin del DIA 22
# Inf: 812 -Vect: 132 -Rec: 532
# Tiempo de simulacion0.0919039249420166
# --------------------------------------------- SIMUACION SEMILLA: 974 ---------------------------------------------
# Fin del DIA 22
# Inf: 788 -Vect: 112 -Rec: 589
# Tiempo de simulacion0.07934427261352539
# --------------------------------------------- SIMUACION SEMILLA: 975 ---------------------------------------------
# Fin del DIA 22
# Inf: 782 -Vect: 125 -Rec: 570
# Tiempo de simulacion0.09000968933105469
# --------------------------------------------- SIMUACION SEMILLA: 976 ---------------------------------------------
# Fin del DIA 22
# Inf: 904 -Vect: 170 -Rec: 453
# Tiempo de simulacion0.08741092681884766
# --------------------------------------------- SIMUACION SEMILLA: 977 ---------------------------------------------
# Fin del DIA 22
# Inf: 845 -Vect: 124 -Rec: 514
# Tiempo de simulacion0.10007309913635254
# --------------------------------------------- SIMUACION SEMILLA: 978 ---------------------------------------------
# Fin del DIA 22
# Inf: 813 -Vect: 142 -Rec: 526
# Tiempo de simulacion0.08862614631652832
# --------------------------------------------- SIMUACION SEMILLA: 979 ---------------------------------------------
# Fin del DIA 22
# Inf: 787 -Vect: 127 -Rec: 558
# Tiempo de simulacion0.09976601600646973
# --------------------------------------------- SIMUACION SEMILLA: 980 ---------------------------------------------
# Fin del DIA 22
# Inf: 0 -Vect: 0 -Rec: 1
# Tiempo de simulacion0.06442403793334961
# --------------------------------------------- SIMUACION SEMILLA: 981 ---------------------------------------------
# Fin del DIA 22
# Inf: 856 -Vect: 176 -Rec: 487
# Tiempo de simulacion0.08134102821350098
# --------------------------------------------- SIMUACION SEMILLA: 982 ---------------------------------------------
# Fin del DIA 22
# Inf: 826 -Vect: 126 -Rec: 532
# Tiempo de simulacion0.09094095230102539
# --------------------------------------------- SIMUACION SEMILLA: 983 ---------------------------------------------
# Fin del DIA 22
# Inf: 923 -Vect: 176 -Rec: 419
# Tiempo de simulacion0.08518719673156738
# --------------------------------------------- SIMUACION SEMILLA: 984 ---------------------------------------------
# Fin del DIA 22
# Inf: 845 -Vect: 136 -Rec: 496
# Tiempo de simulacion0.08622097969055176
# --------------------------------------------- SIMUACION SEMILLA: 985 ---------------------------------------------
# Fin del DIA 22
# Inf: 785 -Vect: 143 -Rec: 590
# Tiempo de simulacion0.08622527122497559
# --------------------------------------------- SIMUACION SEMILLA: 986 ---------------------------------------------
# Fin del DIA 22
# Inf: 854 -Vect: 119 -Rec: 515
# Tiempo de simulacion0.09131789207458496
# --------------------------------------------- SIMUACION SEMILLA: 987 ---------------------------------------------
# Fin del DIA 22
# Inf: 860 -Vect: 146 -Rec: 494
# Tiempo de simulacion0.09078121185302734
# --------------------------------------------- SIMUACION SEMILLA: 988 ---------------------------------------------
# Fin del DIA 22
# Inf: 792 -Vect: 123 -Rec: 577
# Tiempo de simulacion0.08704090118408203
# --------------------------------------------- SIMUACION SEMILLA: 989 ---------------------------------------------
# Fin del DIA 22
# Inf: 823 -Vect: 113 -Rec: 530
# Tiempo de simulacion0.08390593528747559
# --------------------------------------------- SIMUACION SEMILLA: 990 ---------------------------------------------
# Fin del DIA 22
# Inf: 776 -Vect: 135 -Rec: 584
# Tiempo de simulacion0.0952918529510498
# --------------------------------------------- SIMUACION SEMILLA: 991 ---------------------------------------------
# Fin del DIA 22
# Inf: 827 -Vect: 124 -Rec: 518
# Tiempo de simulacion0.09349393844604492
# --------------------------------------------- SIMUACION SEMILLA: 992 ---------------------------------------------
# Fin del DIA 22
# Inf: 840 -Vect: 150 -Rec: 507
# Tiempo de simulacion0.08873963356018066
# --------------------------------------------- SIMUACION SEMILLA: 993 ---------------------------------------------
# Fin del DIA 22
# Inf: 860 -Vect: 154 -Rec: 486
# Tiempo de simulacion0.08307671546936035
# --------------------------------------------- SIMUACION SEMILLA: 994 ---------------------------------------------
# Fin del DIA 22
# Inf: 809 -Vect: 137 -Rec: 557
# Tiempo de simulacion0.08730387687683105
# --------------------------------------------- SIMUACION SEMILLA: 995 ---------------------------------------------
# Fin del DIA 22
# Inf: 816 -Vect: 138 -Rec: 556
# Tiempo de simulacion0.08913707733154297
# --------------------------------------------- SIMUACION SEMILLA: 996 ---------------------------------------------
# Fin del DIA 22
# Inf: 771 -Vect: 99 -Rec: 566
# Tiempo de simulacion0.08267331123352051
# --------------------------------------------- SIMUACION SEMILLA: 997 ---------------------------------------------
# Fin del DIA 22
# Inf: 809 -Vect: 134 -Rec: 539
# Tiempo de simulacion0.08166766166687012
# --------------------------------------------- SIMUACION SEMILLA: 998 ---------------------------------------------
# Fin del DIA 22
# Inf: 843 -Vect: 130 -Rec: 500
# Tiempo de simulacion0.09060525894165039
# --------------------------------------------- SIMUACION SEMILLA: 999 ---------------------------------------------
# Fin del DIA 22
# Inf: 810 -Vect: 128 -Rec: 529
# Tiempo de simulacion0.09022212028503418
# Con 1500 personas y 22 dias se demora 90.13353705406189s en hacer 1000 simulaciones
# Promedio de simulacion0.0901335370540619 s

# %%
probabilidades
# Out:
# {0: 0.575,
#  1: 0.413,
#  2: 0.815,
#  3: 0.548,
#  4: 0.433,
#  5: 0.377,
#  6: 0.674,
#  7: 0.495,
#  8: 0.708,
#  9: 0.507,
#  10: 0.706,
#  11: 0.3,
#  12: 0.681,
#  13: 0.664,
#  14: 0.608,
#  15: 0.46,
#  16: 0.652,
#  17: 0.658,
#  18: 0.635,
#  19: 0.764,
#  20: 0.418,
#  21: 0.383,
#  22: 0.427,
#  23: 0.66,
#  24: 0.447,
#  25: 0.489,
#  26: 0.431,
#  27: 0.074,
#  28: 0.577,
#  29: 0.395,
#  30: 0.483,
#  31: 0.494,
#  32: 0.47,
#  33: 0.022,
#  34: 0.19,
#  35: 0.432,
#  36: 0.683,
#  37: 0.437,
#  38: 0.506,
#  39: 0.674,
#  40: 0.7,
#  41: 0.666,
#  42: 0.75,
#  43: 0.766,
#  44: 0.871,
#  45: 0.48,
#  46: 0.577,
#  47: 0.807,
#  48: 0.326,
#  49: 0.404,
#  50: 0.558,
#  51: 0.588,
#  52: 0.651,
#  53: 0.641,
#  54: 0.336,
#  55: 0.602,
#  56: 0.59,
#  57: 0.612,
#  58: 0.372,
#  59: 0.548,
#  60: 0.289,
#  61: 0.743,
#  62: 0.0,
#  63: 0.673,
#  64: 0.222,
#  65: 0.252,
#  66: 0.556,
#  67: 0.624,
#  68: 0.599,
#  69: 0.332,
#  70: 0.0,
#  71: 0.547,
#  72: 0.393,
#  73: 0.111,
#  74: 0.826,
#  75: 0.886,
#  76: 0.712,
#  77: 0.518,
#  78: 0.531,
#  79: 0.498,
#  80: 0.483,
#  81: 0.473,
#  82: 0.784,
#  83: 0.596,
#  84: 0.697,
#  85: 0.61,
#  86: 0.349,
#  87: 0.704,
#  88: 0.422,
#  89: 0.265,
#  90: 0.44,
#  91: 0.783,
#  92: 0.293,
#  93: 0.884,
#  94: 0.503,
#  95: 0.252,
#  96: 0.464,
#  97: 0.678,
#  98: 0.297,
#  99: 0.681,
#  100: 0.124,
#  101: 0.594,
#  102: 0.336,
#  103: 0.803,
#  104: 0.576,
#  105: 0.631,
#  106: 0.438,
#  107: 0.66,
#  108: 0.304,
#  109: 0.395,
#  110: 0.619,
#  111: 0.836,
#  112: 0.517,
#  113: 0.353,
#  114: 0.544,
#  115: 0.43,
#  116: 0.492,
#  117: 0.727,
#  118: 0.479,
#  119: 0.936,
#  120: 0.86,
#  121: 0.337,
#  122: 0.561,
#  123: 0.724,
#  124: 0.618,
#  125: 0.479,
#  126: 0.758,
#  127: 0.467,
#  128: 0.669,
#  129: 0.886,
#  130: 0.494,
#  131: 0.387,
#  132: 0.69,
#  133: 0.476,
#  134: 0.456,
#  135: 0.656,
#  136: 0.5,
#  137: 0.644,
#  138: 0.777,
#  139: 0.68,
#  140: 0.524,
#  141: 0.627,
#  142: 0.423,
#  143: 0.538,
#  144: 0.931,
#  145: 0.68,
#  146: 0.462,
#  147: 0.338,
#  148: 0.546,
#  149: 0.0,
#  150: 0.7,
#  151: 0.489,
#  152: 0.763,
#  153: 0.531,
#  154: 0.661,
#  155: 0.381,
#  156: 0.714,
#  157: 0.567,
#  158: 0.482,
#  159: 0.822,
#  160: 0.302,
#  161: 0.299,
#  162: 0.677,
#  163: 0.364,
#  164: 0.617,
#  165: 0.0,
#  166: 0.398,
#  167: 0.419,
#  168: 0.424,
#  169: 0.614,
#  170: 0.0,
#  171: 0.838,
#  172: 0.883,
#  173: 0.384,
#  174: 0.471,
#  175: 0.575,
#  176: 0.628,
#  177: 0.721,
#  178: 0.364,
#  179: 0.609,
#  180: 0.447,
#  181: 0.497,
#  182: 0.885,
#  183: 0.736,
#  184: 0.261,
#  185: 0.278,
#  186: 0.621,
#  187: 0.267,
#  188: 0.276,
#  189: 0.599,
#  190: 0.812,
#  191: 0.836,
#  192: 0.825,
#  193: 0.566,
#  194: 0.353,
#  195: 0.562,
#  196: 0.254,
#  197: 0.598,
#  198: 0.78,
#  199: 0.362,
#  200: 0.561,
#  201: 0.661,
#  202: 0.306,
#  203: 0.564,
#  204: 0.571,
#  205: 0.561,
#  206: 0.521,
#  207: 0.643,
#  208: 0.563,
#  209: 0.426,
#  210: 0.0,
#  211: 0.546,
#  212: 0.499,
#  213: 0.471,
#  214: 0.872,
#  215: 0.553,
#  216: 0.524,
#  217: 0.715,
#  218: 0.485,
#  219: 0.487,
#  220: 0.921,
#  221: 0.568,
#  222: 0.692,
#  223: 0.743,
#  224: 0.654,
#  225: 0.527,
#  226: 0.753,
#  227: 0.474,
#  228: 0.217,
#  229: 0.436,
#  230: 0.647,
#  231: 0.534,
#  232: 0.33,
#  233: 0.903,
#  234: 0.594,
#  235: 0.638,
#  236: 0.427,
#  237: 0.782,
#  238: 0.588,
#  239: 0.551,
#  240: 0.49,
#  241: 0.435,
#  242: 0.0,
#  243: 0.252,
#  244: 0.512,
#  245: 0.509,
#  246: 0.476,
#  247: 0.507,
#  248: 0.775,
#  249: 0.408,
#  250: 0.422,
#  251: 0.614,
#  252: 0.597,
#  253: 0.095,
#  254: 0.788,
#  255: 0.707,
#  256: 0.491,
#  257: 0.412,
#  258: 0.339,
#  259: 0.521,
#  260: 0.54,
#  261: 0.0,
#  262: 0.724,
#  263: 0.825,
#  264: 0.234,
#  265: 0.667,
#  266: 0.651,
#  267: 0.513,
#  268: 0.377,
#  269: 0.511,
#  270: 0.932,
#  271: 0.0,
#  272: 0.383,
#  273: 0.409,
#  274: 0.0,
#  275: 0.34,
#  276: 0.516,
#  277: 0.477,
#  278: 0.45,
#  279: 0.601,
#  280: 0.599,
#  281: 0.718,
#  282: 0.61,
#  283: 0.798,
#  284: 0.458,
#  285: 0.458,
#  286: 0.552,
#  287: 0.871,
#  288: 0.559,
#  289: 0.383,
#  290: 0.487,
#  291: 0.865,
#  292: 0.47,
#  293: 0.449,
#  294: 0.777,
#  295: 0.702,
#  296: 0.34,
#  297: 0.73,
#  298: 0.843,
#  299: 0.405,
#  300: 0.429,
#  301: 0.275,
#  302: 0.36,
#  303: 0.462,
#  304: 0.406,
#  305: 0.819,
#  306: 0.465,
#  307: 0.357,
#  308: 0.574,
#  309: 0.853,
#  310: 0.0,
#  311: 0.507,
#  312: 0.821,
#  313: 0.345,
#  314: 0.418,
#  315: 0.68,
#  316: 0.593,
#  317: 0.684,
#  318: 0.622,
#  319: 0.551,
#  320: 0.725,
#  321: 0.529,
#  322: 0.721,
#  323: 0.523,
#  324: 0.0,
#  325: 0.885,
#  326: 0.403,
#  327: 0.471,
#  328: 0.652,
#  329: 0.365,
#  330: 0.538,
#  331: 0.349,
#  332: 0.453,
#  333: 0.833,
#  334: 0.897,
#  335: 0.437,
#  336: 0.35,
#  337: 0.477,
#  338: 0.776,
#  339: 0.061,
#  340: 0.42,
#  341: 0.606,
#  342: 0.633,
#  343: 0.412,
#  344: 0.459,
#  345: 0.475,
#  346: 0.197,
#  347: 0.498,
#  348: 0.37,
#  349: 0.49,
#  350: 0.576,
#  351: 0.0,
#  352: 0.626,
#  353: 0.468,
#  354: 0.667,
#  355: 0.839,
#  356: 0.404,
#  357: 0.624,
#  358: 0.777,
#  359: 0.717,
#  360: 0.708,
#  361: 0.599,
#  362: 0.649,
#  363: 0.444,
#  364: 0.637,
#  365: 0.499,
#  366: 0.723,
#  367: 0.672,
#  368: 0.639,
#  369: 0.508,
#  370: 0.669,
#  371: 0.504,
#  372: 0.612,
#  373: 0.905,
#  374: 0.529,
#  375: 0.528,
#  376: 0.844,
#  377: 0.65,
#  378: 0.632,
#  379: 0.438,
#  380: 0.771,
#  381: 0.0,
#  382: 0.387,
#  383: 0.615,
#  384: 0.91,
#  385: 0.5,
#  386: 0.772,
#  387: 0.585,
#  388: 0.538,
#  389: 0.472,
#  390: 0.502,
#  391: 0.755,
#  392: 0.32,
#  393: 0.646,
#  394: 0.84,
#  395: 0.406,
#  396: 0.524,
#  397: 0.335,
#  398: 0.761,
#  399: 0.499,
#  400: 0.407,
#  401: 0.615,
#  402: 0.916,
#  403: 0.38,
#  404: 0.426,
#  405: 0.78,
#  406: 0.639,
#  407: 0.418,
#  408: 0.798,
#  409: 0.71,
#  410: 0.592,
#  411: 0.476,
#  412: 0.307,
#  413: 0.0,
#  414: 0.41,
#  415: 0.651,
#  416: 0.659,
#  417: 0.561,
#  418: 0.644,
#  419: 0.644,
#  420: 0.466,
#  421: 0.492,
#  422: 0.426,
#  423: 0.0,
#  424: 0.441,
#  425: 0.352,
#  426: 0.508,
#  427: 0.457,
#  428: 0.489,
#  429: 0.255,
#  430: 0.646,
#  431: 0.636,
#  432: 0.54,
#  433: 0.283,
#  434: 0.5,
#  435: 0.639,
#  436: 0.779,
#  437: 0.686,
#  438: 0.633,
#  439: 0.646,
#  440: 0.897,
#  441: 0.527,
#  442: 0.446,
#  443: 0.46,
#  444: 0.351,
#  445: 0.408,
#  446: 0.502,
#  447: 0.774,
#  448: 0.569,
#  449: 0.289,
#  450: 0.634,
#  451: 0.869,
#  452: 0.261,
#  453: 0.433,
#  454: 0.524,
#  455: 0.676,
#  456: 0.393,
#  457: 0.403,
#  458: 0.299,
#  459: 0.758,
#  460: 0.184,
#  461: 0.852,
#  462: 0.481,
#  463: 0.674,
#  464: 0.588,
#  465: 0.512,
#  466: 0.612,
#  467: 0.866,
#  468: 0.475,
#  469: 0.633,
#  470: 0.514,
#  471: 0.499,
#  472: 0.372,
#  473: 0.613,
#  474: 0.884,
#  475: 0.416,
#  476: 0.423,
#  477: 0.545,
#  478: 0.331,
#  479: 0.773,
#  480: 0.507,
#  481: 0.6,
#  482: 0.291,
#  483: 0.591,
#  484: 0.49,
#  485: 0.486,
#  486: 0.622,
#  487: 0.386,
#  488: 0.61,
#  489: 0.512,
#  490: 0.868,
#  491: 0.826,
#  492: 0.551,
#  493: 0.3,
#  494: 0.459,
#  495: 0.577,
#  496: 0.519,
#  497: 0.312,
#  498: 0.654,
#  499: 0.444,
#  500: 0.48,
#  501: 0.303,
#  502: 0.445,
#  503: 0.426,
#  504: 0.414,
#  505: 0.642,
#  506: 0.346,
#  507: 0.213,
#  508: 0.653,
#  509: 0.514,
#  510: 0.61,
#  511: 0.645,
#  512: 0.257,
#  513: 0.655,
#  514: 0.533,
#  515: 0.599,
#  516: 0.624,
#  517: 0.537,
#  518: 0.796,
#  519: 0.792,
#  520: 0.529,
#  521: 0.404,
#  522: 0.599,
#  523: 0.325,
#  524: 0.726,
#  525: 0.559,
#  526: 0.803,
#  527: 0.294,
#  528: 0.224,
#  529: 0.366,
#  530: 0.43,
#  531: 0.565,
#  532: 0.631,
#  533: 0.492,
#  534: 0.595,
#  535: 0.623,
#  536: 0.47,
#  537: 0.397,
#  538: 0.648,
#  539: 0.434,
#  540: 0.727,
#  541: 0.441,
#  542: 0.53,
#  543: 0.36,
#  544: 0.387,
#  545: 0.568,
#  546: 0.596,
#  547: 0.569,
#  548: 0.324,
#  549: 0.519,
#  550: 0.53,
#  551: 0.492,
#  552: 0.447,
#  553: 0.111,
#  554: 0.866,
#  555: 0.639,
#  556: 0.408,
#  557: 0.54,
#  558: 0.478,
#  559: 0.0,
#  560: 0.486,
#  561: 0.44,
#  562: 0.443,
#  563: 0.623,
#  564: 0.757,
#  565: 0.732,
#  566: 0.652,
#  567: 0.615,
#  568: 0.611,
#  569: 0.285,
#  570: 0.313,
#  571: 0.458,
#  572: 0.455,
#  573: 0.854,
#  574: 0.555,
#  575: 0.862,
#  576: 0.746,
#  577: 0.59,
#  578: 0.488,
#  579: 0.069,
#  580: 0.483,
#  581: 0.573,
#  582: 0.7,
#  583: 0.599,
#  584: 0.451,
#  585: 0.389,
#  586: 0.657,
#  587: 0.392,
#  588: 0.885,
#  589: 0.275,
#  590: 0.824,
#  591: 0.593,
#  592: 0.445,
#  593: 0.399,
#  594: 0.41,
#  595: 0.484,
#  596: 0.43,
#  597: 0.48,
#  598: 0.365,
#  599: 0.524,
#  600: 0.677,
#  601: 0.763,
#  602: 0.658,
#  603: 0.43,
#  604: 0.731,
#  605: 0.649,
#  606: 0.368,
#  607: 0.351,
#  608: 0.681,
#  609: 0.398,
#  610: 0.506,
#  611: 0.506,
#  612: 0.476,
#  613: 0.575,
#  614: 0.616,
#  615: 0.696,
#  616: 0.349,
#  617: 0.244,
#  618: 0.57,
#  619: 0.508,
#  620: 0.438,
#  621: 0.549,
#  622: 0.421,
#  623: 0.76,
#  624: 0.475,
#  625: 0.0,
#  626: 0.585,
#  627: 0.594,
#  628: 0.499,
#  629: 0.391,
#  630: 0.414,
#  631: 0.461,
#  632: 0.369,
#  633: 0.366,
#  634: 0.604,
#  635: 0.571,
#  636: 0.73,
#  637: 0.414,
#  638: 0.551,
#  639: 0.827,
#  640: 0.626,
#  641: 0.697,
#  642: 0.562,
#  643: 0.841,
#  644: 0.609,
#  645: 0.602,
#  646: 0.495,
#  647: 0.766,
#  648: 0.808,
#  649: 0.668,
#  650: 0.766,
#  651: 0.544,
#  652: 0.895,
#  653: 0.702,
#  654: 0.527,
#  655: 0.521,
#  656: 0.845,
#  657: 0.673,
#  658: 0.654,
#  659: 0.453,
#  660: 0.493,
#  661: 0.278,
#  662: 0.786,
#  663: 0.842,
#  664: 0.838,
#  665: 0.546,
#  666: 0.364,
#  667: 0.778,
#  668: 0.262,
#  669: 0.0,
#  670: 0.765,
#  671: 0.351,
#  672: 0.478,
#  673: 0.458,
#  674: 0.448,
#  675: 0.214,
#  676: 0.367,
#  677: 0.798,
#  678: 0.199,
#  679: 0.463,
#  680: 0.0,
#  681: 0.508,
#  682: 0.526,
#  683: 0.432,
#  684: 0.277,
#  685: 0.585,
#  686: 0.4,
#  687: 0.72,
#  688: 0.453,
#  689: 0.685,
#  690: 0.172,
#  691: 0.415,
#  692: 0.221,
#  693: 0.093,
#  694: 0.609,
#  695: 0.812,
#  696: 0.467,
#  697: 0.679,
#  698: 0.665,
#  699: 0.596,
#  700: 0.901,
#  701: 0.656,
#  702: 0.712,
#  703: 0.563,
#  704: 0.683,
#  705: 0.274,
#  706: 0.472,
#  707: 0.849,
#  708: 0.469,
#  709: 0.325,
#  710: 0.68,
#  711: 0.476,
#  712: 0.382,
#  713: 0.457,
#  714: 0.495,
#  715: 0.607,
#  716: 0.524,
#  717: 0.457,
#  718: 0.39,
#  719: 0.569,
#  720: 0.656,
#  721: 0.821,
#  722: 0.518,
#  723: 0.362,
#  724: 0.338,
#  725: 0.286,
#  726: 0.307,
#  727: 0.383,
#  728: 0.835,
#  729: 0.446,
#  730: 0.573,
#  731: 0.797,
#  732: 0.614,
#  733: 0.699,
#  734: 0.0,
#  735: 0.491,
#  736: 0.723,
#  737: 0.54,
#  738: 0.63,
#  739: 0.614,
#  740: 0.795,
#  741: 0.572,
#  742: 0.779,
#  743: 0.329,
#  744: 0.334,
#  745: 0.475,
#  746: 0.469,
#  747: 0.62,
#  748: 0.779,
#  749: 0.336,
#  750: 0.541,
#  751: 0.584,
#  752: 0.468,
#  753: 0.442,
#  754: 0.208,
#  755: 0.732,
#  756: 0.232,
#  757: 0.514,
#  758: 0.646,
#  759: 0.352,
#  760: 0.772,
#  761: 0.53,
#  762: 0.539,
#  763: 0.546,
#  764: 0.592,
#  765: 0.582,
#  766: 0.694,
#  767: 0.484,
#  768: 0.537,
#  769: 0.397,
#  770: 0.606,
#  771: 0.419,
#  772: 0.486,
#  773: 0.696,
#  774: 0.567,
#  775: 0.676,
#  776: 0.607,
#  777: 0.65,
#  778: 0.655,
#  779: 0.592,
#  780: 0.637,
#  781: 0.551,
#  782: 0.579,
#  783: 0.514,
#  784: 0.542,
#  785: 0.85,
#  786: 0.653,
#  787: 0.386,
#  788: 0.602,
#  789: 0.58,
#  790: 0.407,
#  791: 0.595,
#  792: 0.588,
#  793: 0.293,
#  794: 0.358,
#  795: 0.81,
#  796: 0.45,
#  797: 0.316,
#  798: 0.643,
#  799: 0.743,
#  800: 0.667,
#  801: 0.714,
#  802: 0.39,
#  803: 0.457,
#  804: 0.225,
#  805: 0.931,
#  806: 0.298,
#  807: 0.441,
#  808: 0.584,
#  809: 0.759,
#  810: 0.41,
#  811: 0.71,
#  812: 0.549,
#  813: 0.415,
#  814: 0.492,
#  815: 0.495,
#  816: 0.381,
#  817: 0.433,
#  818: 0.715,
#  819: 0.708,
#  820: 0.601,
#  821: 0.497,
#  822: 0.465,
#  823: 0.381,
#  824: 0.544,
#  825: 0.869,
#  826: 0.453,
#  827: 0.682,
#  828: 0.096,
#  829: 0.897,
#  830: 0.297,
#  831: 0.719,
#  832: 0.571,
#  833: 0.711,
#  834: 0.454,
#  835: 0.689,
#  836: 0.136,
#  837: 0.641,
#  838: 0.652,
#  839: 0.744,
#  840: 0.651,
#  841: 0.409,
#  842: 0.636,
#  843: 0.684,
#  844: 0.527,
#  845: 0.502,
#  846: 0.721,
#  847: 0.545,
#  848: 0.464,
#  849: 0.428,
#  850: 0.435,
#  851: 0.64,
#  852: 0.631,
#  853: 0.434,
#  854: 0.419,
#  855: 0.919,
#  856: 0.383,
#  857: 0.816,
#  858: 0.827,
#  859: 0.56,
#  860: 0.376,
#  861: 0.568,
#  862: 0.691,
#  863: 0.775,
#  864: 0.414,
#  865: 0.393,
#  866: 0.634,
#  867: 0.52,
#  868: 0.362,
#  869: 0.588,
#  870: 0.88,
#  871: 0.544,
#  872: 0.353,
#  873: 0.457,
#  874: 0.587,
#  875: 0.357,
#  876: 0.226,
#  877: 0.591,
#  878: 0.524,
#  879: 0.491,
#  880: 0.831,
#  881: 0.411,
#  882: 0.511,
#  883: 0.488,
#  884: 0.735,
#  885: 0.406,
#  886: 0.641,
#  887: 0.466,
#  888: 0.613,
#  889: 0.39,
#  890: 0.401,
#  891: 0.694,
#  892: 0.341,
#  893: 0.463,
#  894: 0.513,
#  895: 0.432,
#  896: 0.831,
#  897: 0.8,
#  898: 0.813,
#  899: 0.414,
#  900: 0.0,
#  901: 0.552,
#  902: 0.694,
#  903: 0.59,
#  904: 0.601,
#  905: 0.801,
#  906: 0.452,
#  907: 0.237,
#  908: 0.517,
#  909: 0.402,
#  910: 0.698,
#  911: 0.364,
#  912: 0.57,
#  913: 0.696,
#  914: 0.623,
#  915: 0.443,
#  916: 0.499,
#  917: 0.367,
#  918: 0.269,
#  919: 0.326,
#  920: 0.306,
#  921: 0.561,
#  922: 0.268,
#  923: 0.344,
#  924: 0.788,
#  925: 0.015,
#  926: 0.439,
#  927: 0.506,
#  928: 0.598,
#  929: 0.603,
#  930: 0.768,
#  931: 0.708,
#  932: 0.534,
#  933: 0.656,
#  934: 0.418,
#  935: 0.674,
#  936: 0.519,
#  937: 0.211,
#  938: 0.45,
#  939: 0.0,
#  940: 0.664,
#  941: 0.629,
#  942: 0.221,
#  943: 0.417,
#  944: 0.422,
#  945: 0.752,
#  946: 0.101,
#  947: 0.891,
#  948: 0.574,
#  949: 0.302,
#  950: 0.49,
#  951: 0.79,
#  952: 0.718,
#  953: 0.566,
#  954: 0.792,
#  955: 0.767,
#  956: 0.584,
#  957: 0.664,
#  958: 0.515,
#  959: 0.426,
#  960: 0.466,
#  961: 0.0,
#  962: 0.403,
#  963: 0.48,
#  964: 0.683,
#  965: 0.506,
#  966: 0.407,
#  967: 0.498,
#  968: 0.744,
#  969: 0.765,
#  970: 0.685,
#  971: 0.559,
#  972: 0.305,
#  973: 0.525,
#  974: 0.778,
#  975: 0.622,
#  976: 0.362,
#  977: 0.631,
#  978: 0.462,
#  979: 0.351,
#  980: 0.395,
#  981: 0.445,
#  982: 0.516,
#  983: 0.479,
#  984: 0.608,
#  985: 0.48,
#  986: 0.8,
#  987: 0.568,
#  988: 0.825,
#  989: 0.578,
#  990: 0.598,
#  991: 0.58,
#  992: 0.571,
#  993: 0.657,
#  994: 0.383,
#  995: 0.572,
#  996: 0.579,
#  997: 0.634,
#  998: 0.653,
#  999: 0.709,
#  ...}

# %% [markdown]
# cada funcion debería ser ejecutada con los parámetros dichos en el enunciado

# %% [markdown]
# Para analizar cualitativamente, tengo que especificar la instancia y la semilla, y comentar la wea
#
# POR como son los datos cuando se corren los 75 las probabilidades tienden a ser 0 o muy bajas
